# %% [markdown]
# # Du scrapping à la reconnaissance d'entités nommées

# %% [markdown]
# Pour reconnaissance les noms des députés, je reprends le code utilisé pour scrapper les informations les concernant.

# %% [markdown]
# ## Code de scrapping d'AGODA

# %%
def scrap_AN_AGODA(debut, fin):
    import requests
    import bs4 as bs
    import pandas as pd
    debut = int(debut)
    fin = int(fin + 1)
    legislatures = range(debut, fin)
    url = "http://www2.assemblee-nationale.fr/sycomore/liste/(legislature)/"
    df_complet = pd.DataFrame(columns=["id_depute", "nom", "prenom", "lien","naissance_j", "naissance_m", "naissance_a", "deces_j", "deces_m", "deces_a" ])

    for leg in legislatures:
        mois = {"janvier": "1", "février": "2", "mars": "3", "avril": "4", "mai": "5", "juin": "6",\
                "juillet": "7", "août": "7", "septembre": "9", "octobre": "10", "novembre": "11", "décembre": "12"}
        r = requests.get(url + str(leg))
        pageWeb = r.text
        localisation_depart = pageWeb.find("<table class=\"sycomore\">")
        localisation_fin = pageWeb.find("</table>")
        tableau_seul = pageWeb[localisation_depart:localisation_fin]
        soup = bs.BeautifulSoup(tableau_seul, 'lxml')
        all_tr = list(soup.find_all("tr"))
        all_tr_data = all_tr[1:]
        
        nom = []
        prenom = []
        lien = []
        id_depute = []
        date_naissance = []
        date_deces = []
        
        for data in all_tr_data:
            
            id_depute.append(int(data.find('a').get('href').replace("/sycomore/fiche/(num_dept)/", "")))
            nom.append(data.td['data-sort'])
            prenom.append(data.td.get_text().replace(data.find('strong').string, "").strip())
            lien.append("http://www2.assemblee-nationale.fr" + data.find('a').get('href'))
            date_naissance.append(data.find_all('td')[1].string)
            date_deces.append(data.find_all('td')[2].string)
    
        data_dic = {"id_depute": id_depute, 
                    "nom": nom, 
                    "prenom": prenom, 
                    "lien": lien, 
                    "date_naissance": date_naissance,
                    "date_deces": date_deces} 

        df = pd.DataFrame(data_dic)
        df[["date_naissance", "naissance_m", "naissance_a"]] = df["date_naissance"].str.split(expand=True).replace("1er", "1")
        df[["date_deces", "deces_m", "deces_a"]] = df["date_deces"].str.split(expand=True).replace("1er", "1")
        df.rename(columns = {"date_naissance": "naissance_j", "date_deces": "deces_j"}, inplace=True)
        df = df[["id_depute", "nom", "prenom", "lien","naissance_j", "naissance_m", "naissance_a",\
                 "deces_j", "deces_m", "deces_a" ]]
       
        df["naissance_m"] = df["naissance_m"].map(mois, na_action = 'ignore')
        df["deces_m"] = df["deces_m"].map(mois, na_action = 'ignore')
# On enregistre localement le DF contenant la liste des députés de la législature | changement personnel
        chemin_fichier_csv = "/Users/charlielezin/Desktop/test_scrapping_députés/scrap_AGODA.csv" 
        df.to_csv(chemin_fichier_csv, sep=",", index=False)
# On insère la liste des députés de la législature dans le DF df_complet en supprimant les doublons
        df_complet = pd.concat([df_complet, df], ignore_index=True).drop_duplicates()
    
    df_complet.to_csv("legislature" + str(debut) + "_" + str(fin - 1))
    return df_complet ## ajout de ligne

# %%
df_general = scrap_AN_AGODA(47, 47)

# %%
df_general
# Out:
#     id_depute                nom                         prenom  \
# 0          19             Abelin  Pierre, Louis, Ernest, Armand
# 1          79              Alduy                           Paul
# 2          94             Alliot  Edouard, Denis, Marie, Joseph
# 3          97             Alloin                   Louis, Marie
# 4         132              André                         Pierre
# ..        ...                ...                            ...
# 610      7235            Villard                           Jean
# 611      7237  Villon-Ginsburger                         Pierre
# 612      7259             Vitter    Pierre, Joseph, Louis, Léon
# 613      7243           Vuillien                          André
# 614      7246             Wasmer                         Joseph
#
#                                                   lien naissance_j  \
# 0    http://www2.assemblee-nationale.fr/sycomore/fi...          16
# 1    http://www2.assemblee-nationale.fr/sycomore/fi...           4
# 2    http://www2.assemblee-nationale.fr/sycomore/fi...          26
# 3    http://www2.assemblee-nationale.fr/sycomore/fi...           3
# 4    http://www2.assemblee-nationale.fr/sycomore/fi...          27
# ..                                                 ...         ...
# 610  http://www2.assemblee-nationale.fr/sycomore/fi...          24
# 611  http://www2.assemblee-nationale.fr/sycomore/fi...          27
# 612  http://www2.assemblee-nationale.fr/sycomore/fi...          29
# 613  http://www2.assemblee-nationale.fr/sycomore/fi...           9
# 614  http://www2.assemblee-nationale.fr/sycomore/fi...           1
#
#     naissance_m naissance_a deces_j deces_m deces_a
# 0             5        1909      23       5    1977
# 1            10        1914      23       1    2006
# 2             2        1900      16      11    1981
# 3             7        1906      28      12    1978
# 4            10        1903       9       4    1984
# ..          ...         ...     ...     ...     ...
# 610           2        1907      10      12    1986
# 611           7        1901       6      11    1980
# 612          10        1913      26      10    1995
# 613           2        1924       6       5    2016
# 614           9        1910      13       4    1995
#
# [615 rows x 10 columns]

# %% [markdown]
# ## Mon scrap, adapté d'AGODA

# %%
def mon_scrap_AN(debut, fin):
    import requests
    import bs4 as bs
    import pandas as pd
    
    debut = int(debut)
    fin = int(fin + 1)
    legislatures = range(debut, fin)
    url = "https://www2.assemblee-nationale.fr/sycomore/liste/(legislature)/"
    df_complet = pd.DataFrame(columns=["lien", "groupe_parlementaire", "departement"])

    for leg in legislatures:
        r = requests.get(url + str(leg) + "/(alpha)/true")
        pageWeb = r.text
        localisation_depart = pageWeb.find("<article>")
        localisation_fin = pageWeb.find("</article>")
        tableau_seul = pageWeb[localisation_depart:localisation_fin]
        soup = bs.BeautifulSoup(tableau_seul, 'lxml')
        all_li = list(soup.find_all("li"))
        all_li_data = all_li[1:]

        lien = []
        groupe_parlementaire = []
        departement = []
        

        for data in all_li_data:
            a_tag = data.find("a")
            lien.append("http://www2.assemblee-nationale.fr" + a_tag.get('href'))

            # Extraction du groupe parlementaire du député
            groupe_element = data.find("span", class_="block bottommargin")
            if groupe_element is not None:
                groupe_i_element = groupe_element.find("i")
                groupe_text = groupe_i_element.text.strip() if groupe_i_element is not None else ""
                groupe_text = groupe_text.replace("(", "").replace(")", "")
                groupe_parlementaire.append(groupe_text)
            else:
                groupe_parlementaire.append("")

            # Extraction du département du député
            departement_element = data.find("span", class_="block bottommargin")
            if departement_element is not None:
                departement_span_elements = departement_element.find_all("span")
                if len(departement_span_elements) >= 2:
                    departement_text = departement_span_elements[1].text.strip().replace(" - ", "")
                    departement_text = departement_text.replace("(", "").replace(")", "")
                    departement.append(departement_text)
                else:
                    departement.append("")
            else:
                departement.append("")
                                   
        data_dic = {
                    "lien": lien,
                    "groupe_parlementaire": groupe_parlementaire,
                    "departement": departement
                    
                }

        df = pd.DataFrame(data_dic)
        df = df[["lien", "groupe_parlementaire", "departement"]]
        df[['departement', 'groupe_parlementaire']] = df['groupe_parlementaire'].str.split(' - ', 1, expand=True)
        df_complet = df_complet.append(df, ignore_index=True)

# On enregistre localement le DF contenant la liste des députés de la législature | changement personnel
        chemin_fichier_csv = "/Users/charlielezin/Desktop/test_scrapping_députés/scrap_groupe_dep2.csv" 
        df.to_csv(chemin_fichier_csv, sep=",", index=False)
# On insère la liste des députés de la législature dans le DF df_complet en supprimant les doublons
        df_complet = pd.concat([df_complet, df], ignore_index=True).drop_duplicates()

    df_complet.to_csv("legislature" + str(debut) + "_" + str(fin - 1) + ".csv", sep=",", index=False)
    return df_complet ## ajout de ligne

# %%
df_groupe_dep = mon_scrap_AN(47, 47)
# Out:
# /var/folders/py/k9l9n4nj5l966__zkxgrfsj00000gn/T/ipykernel_45943/3622332321.py:64: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_complet = df_complet.append(df, ignore_index=True)

# %%
df_groupe_dep
# Out:
#                                                   lien  \
# 0    http://www2.assemblee-nationale.fr/sycomore/fi...
# 1    http://www2.assemblee-nationale.fr/sycomore/fi...
# 2    http://www2.assemblee-nationale.fr/sycomore/fi...
# 3    http://www2.assemblee-nationale.fr/sycomore/fi...
# 4    http://www2.assemblee-nationale.fr/sycomore/fi...
# ..                                                 ...
# 609  http://www2.assemblee-nationale.fr/sycomore/fi...
# 610  http://www2.assemblee-nationale.fr/sycomore/fi...
# 611  http://www2.assemblee-nationale.fr/sycomore/fi...
# 612  http://www2.assemblee-nationale.fr/sycomore/fi...
# 613  http://www2.assemblee-nationale.fr/sycomore/fi...
#
#                           groupe_parlementaire          departement
# 0                                   Socialiste  Pyrénées-Orientales
# 1     Indépendants et paysans d'action sociale                Aisne
# 2                Union et fraternité francaise                Rhône
# 3     Indépendants et paysans d'action sociale   Meurthe-et-Moselle
# 4    Républicain radical et radical-socialiste               Vienne
# ..                                         ...                  ...
# 609            Mouvement républicain populaire                Rhône
# 610                                 Communiste               Allier
# 611                                     Paysan          Haute-Saône
# 612                                 Communiste       Saône-et-Loire
# 613            Mouvement républicain populaire            Haut-Rhin
#
# [614 rows x 3 columns]

# %%
import pandas as pd
# Ajout des informations du député Abelin
nouvelle_ligne = pd.Series({'lien': 'http://www2.assemblee-nationale.fr/sycomore/fiche/(num_dept)/19/(legislature)/47', 
                            'groupe_parlementaire': 'Mouvement républicain populaire', 'departement': 'Vienne'})

# Utiliser la méthode concat pour ajouter la nouvelle ligne en tant que première ligne
df_groupe_dep = pd.concat([nouvelle_ligne.to_frame().transpose(), df_groupe_dep], ignore_index=True)

# %%
df_groupe_dep ## 615 députés
# Out:
#                                                   lien  \
# 0    http://www2.assemblee-nationale.fr/sycomore/fi...
# 1    http://www2.assemblee-nationale.fr/sycomore/fi...
# 2    http://www2.assemblee-nationale.fr/sycomore/fi...
# 3    http://www2.assemblee-nationale.fr/sycomore/fi...
# 4    http://www2.assemblee-nationale.fr/sycomore/fi...
# ..                                                 ...
# 610  http://www2.assemblee-nationale.fr/sycomore/fi...
# 611  http://www2.assemblee-nationale.fr/sycomore/fi...
# 612  http://www2.assemblee-nationale.fr/sycomore/fi...
# 613  http://www2.assemblee-nationale.fr/sycomore/fi...
# 614  http://www2.assemblee-nationale.fr/sycomore/fi...
#
#                          groupe_parlementaire          departement
# 0             Mouvement républicain populaire               Vienne
# 1                                  Socialiste  Pyrénées-Orientales
# 2    Indépendants et paysans d'action sociale                Aisne
# 3               Union et fraternité francaise                Rhône
# 4    Indépendants et paysans d'action sociale   Meurthe-et-Moselle
# ..                                        ...                  ...
# 610           Mouvement républicain populaire                Rhône
# 611                                Communiste               Allier
# 612                                    Paysan          Haute-Saône
# 613                                Communiste       Saône-et-Loire
# 614           Mouvement républicain populaire            Haut-Rhin
#
# [615 rows x 3 columns]

# %%
# Je supprime la colonne lien, qui m'a servi à vérifier si les informations revenaient dans le même ordre
# à partir de mon code et avec celui d'AGODA
df_groupe_dep = df_groupe_dep.drop('lien', axis=1)
df_groupe_dep
# Out:
#                          groupe_parlementaire          departement
# 0             Mouvement républicain populaire               Vienne
# 1                                  Socialiste  Pyrénées-Orientales
# 2    Indépendants et paysans d'action sociale                Aisne
# 3               Union et fraternité francaise                Rhône
# 4    Indépendants et paysans d'action sociale   Meurthe-et-Moselle
# ..                                        ...                  ...
# 610           Mouvement républicain populaire                Rhône
# 611                                Communiste               Allier
# 612                                    Paysan          Haute-Saône
# 613                                Communiste       Saône-et-Loire
# 614           Mouvement républicain populaire            Haut-Rhin
#
# [615 rows x 2 columns]

# %%
df_final = pd.concat([df_general, df_groupe_dep], axis=1) ## je concatène les deux dataframe

# %%
df_final
# Out:
#     id_depute                nom                         prenom  \
# 0          19             Abelin  Pierre, Louis, Ernest, Armand
# 1          79              Alduy                           Paul
# 2          94             Alliot  Edouard, Denis, Marie, Joseph
# 3          97             Alloin                   Louis, Marie
# 4         132              André                         Pierre
# ..        ...                ...                            ...
# 610      7235            Villard                           Jean
# 611      7237  Villon-Ginsburger                         Pierre
# 612      7259             Vitter    Pierre, Joseph, Louis, Léon
# 613      7243           Vuillien                          André
# 614      7246             Wasmer                         Joseph
#
#                                                   lien naissance_j  \
# 0    http://www2.assemblee-nationale.fr/sycomore/fi...          16
# 1    http://www2.assemblee-nationale.fr/sycomore/fi...           4
# 2    http://www2.assemblee-nationale.fr/sycomore/fi...          26
# 3    http://www2.assemblee-nationale.fr/sycomore/fi...           3
# 4    http://www2.assemblee-nationale.fr/sycomore/fi...          27
# ..                                                 ...         ...
# 610  http://www2.assemblee-nationale.fr/sycomore/fi...          24
# 611  http://www2.assemblee-nationale.fr/sycomore/fi...          27
# 612  http://www2.assemblee-nationale.fr/sycomore/fi...          29
# 613  http://www2.assemblee-nationale.fr/sycomore/fi...           9
# 614  http://www2.assemblee-nationale.fr/sycomore/fi...           1
#
#     naissance_m naissance_a deces_j deces_m deces_a  \
# 0             5        1909      23       5    1977
# 1            10        1914      23       1    2006
# 2             2        1900      16      11    1981
# 3             7        1906      28      12    1978
# 4            10        1903       9       4    1984
# ..          ...         ...     ...     ...     ...
# 610           2        1907      10      12    1986
# 611           7        1901       6      11    1980
# 612          10        1913      26      10    1995
# 613           2        1924       6       5    2016
# 614           9        1910      13       4    1995
#
#                          groupe_parlementaire          departement
# 0             Mouvement républicain populaire               Vienne
# 1                                  Socialiste  Pyrénées-Orientales
# 2    Indépendants et paysans d'action sociale                Aisne
# 3               Union et fraternité francaise                Rhône
# 4    Indépendants et paysans d'action sociale   Meurthe-et-Moselle
# ..                                        ...                  ...
# 610           Mouvement républicain populaire                Rhône
# 611                                Communiste               Allier
# 612                                    Paysan          Haute-Saône
# 613                                Communiste       Saône-et-Loire
# 614           Mouvement républicain populaire            Haut-Rhin
#
# [615 rows x 12 columns]

# %%
import pandas as pd

# J'exporte le DataFrame dans un fichier CSV
df_final.to_csv('informations_députés.csv', index=False)

# %%
# Compter le nombre d'occurrences dans la colonne 'groupe_parlementaire'
occurrences = df_final['groupe_parlementaire'].value_counts()

# Afficher les résultats
print(occurrences)
# Out:
# Communiste                                                          145
# Socialiste                                                          101
# Indépendants et paysans d'action sociale                             88
# Mouvement républicain populaire                                      74
# Républicain radical et radical-socialiste                            60
# Union et fraternité francaise                                        38
# Républicains sociaux                                                 24
# Union démocratique et socialiste de la Résistance et du RDA          21
# Union et fraternité française                                        14
# Rassemblement des gauches républicaines et du centre républicain     14
# Paysan                                                               13
# Indépendants d'outre-mer                                             10
# Républicain progressiste                                              5
# Non inscrit                                                           4
# Non-inscrit                                                           2
# Non inscrit                                                           1
# Name: groupe_parlementaire, dtype: int64

# %%
groupes_parlementaires = ['Communiste', 'Socialiste', 'Républicain radical et radical-socialiste', 'Union démocratique et socialiste de la Résistance et du RDA']

df_gauche = df_final[df_final['groupe_parlementaire'].isin(groupes_parlementaires)]

# %%
df_gauche
# Out:
#     id_depute                nom                    prenom  \
# 1          79              Alduy                      Paul
# 5         128              André  Adrien, Baptiste, Honoré
# 7         153             Ansart                   Gustave
# 10        165          Anxionnaz              Paul, Marius
# 12        176          Arbeltier              René, Albert
# ..        ...                ...                       ...
# 602      7221             Vergès                      Paul
# 603      7222  Vermeersch-Thorez                 Jeannette
# 604      7226      Véry-Hermence                  Emmanuel
# 611      7237  Villon-Ginsburger                    Pierre
# 613      7243           Vuillien                     André
#
#                                                   lien naissance_j  \
# 1    http://www2.assemblee-nationale.fr/sycomore/fi...           4
# 5    http://www2.assemblee-nationale.fr/sycomore/fi...          29
# 7    http://www2.assemblee-nationale.fr/sycomore/fi...           5
# 10   http://www2.assemblee-nationale.fr/sycomore/fi...          31
# 12   http://www2.assemblee-nationale.fr/sycomore/fi...          23
# ..                                                 ...         ...
# 602  http://www2.assemblee-nationale.fr/sycomore/fi...           5
# 603  http://www2.assemblee-nationale.fr/sycomore/fi...          26
# 604  http://www2.assemblee-nationale.fr/sycomore/fi...          31
# 611  http://www2.assemblee-nationale.fr/sycomore/fi...          27
# 613  http://www2.assemblee-nationale.fr/sycomore/fi...           9
#
#     naissance_m naissance_a deces_j deces_m deces_a  \
# 1            10        1914      23       1    2006
# 5             5        1884      22       4    1965
# 7             3        1923      20       9    1990
# 10           12        1902      20       2    1997
# 12            1        1897      10       9    1979
# ..          ...         ...     ...     ...     ...
# 602           3        1925      12      11    2016
# 603          11        1910       5      11    2001
# 604           3        1904      19       6    1966
# 611           7        1901       6      11    1980
# 613           2        1924       6       5    2016
#
#                           groupe_parlementaire          departement
# 1                                   Socialiste  Pyrénées-Orientales
# 5    Républicain radical et radical-socialiste               Vienne
# 7                                   Communiste                 Nord
# 10   Républicain radical et radical-socialiste                Marne
# 12                                  Socialiste       Seine-et-Marne
# ..                                         ...                  ...
# 602                                 Communiste           La Réunion
# 603                                 Communiste                Seine
# 604                                 Socialiste           Martinique
# 611                                 Communiste               Allier
# 613                                 Communiste       Saône-et-Loire
#
# [327 rows x 12 columns]

# %%
df_gauche.to_csv('deputes_gauche.csv', index=False)

# %% [markdown]
# ## Reconnaissance d'entités nommées

# %% [markdown]
# #### Création d'un dictionnaire à partir du df_gauche

# %%
# Conversion du DataFrame en dictionnaire
deputes_gauche_dict1 = df_gauche[['nom', 'prenom']].to_dict(orient='records')

print(deputes_gauche_dict1)
# Out:
# [{'nom': 'Alduy', 'prenom': 'Paul'}, {'nom': 'André', 'prenom': 'Adrien, Baptiste, Honoré'}, {'nom': 'Ansart', 'prenom': 'Gustave'}, {'nom': 'Anxionnaz', 'prenom': 'Paul, Marius'}, {'nom': 'Arbeltier', 'prenom': 'René, Albert'}, {'nom': 'Arnal', 'prenom': 'Franck'}, {'nom': 'Arrighi', 'prenom': 'Pascal'}, {'nom': 'Auban', 'prenom': 'Achille, Joseph'}, {'nom': 'Babet', 'prenom': 'Raphaël, Jean-Baptiste, Benjamin'}, {'nom': 'Badie', 'prenom': 'Vincent, Henri'}, {'nom': 'Ballanger', 'prenom': 'Robert, Victor, Marcel, François'}, {'nom': 'Barbot', 'prenom': 'Marcel'}, {'nom': 'Barel', 'prenom': 'Joseph dit Virgile'}, {'nom': 'Barry', 'prenom': 'Diawadou'}, {'nom': 'Barthélémy', 'prenom': 'André, Jules, François'}, {'nom': 'Bartolini', 'prenom': 'Jean, Baptiste'}, {'nom': 'Baurens', 'prenom': 'Alexandre, Sylvain, Justin'}, {'nom': 'Baylet', 'prenom': 'Jean, André, Bernard'}, {'nom': 'Bégouin', 'prenom': 'Lucien, Louis, Marie'}, {'nom': 'Béné', 'prenom': 'Maurice'}, {'nom': 'Benoist', 'prenom': 'Charles, Claude'}, {'nom': 'Benoit', 'prenom': 'Alcide, Alfred'}, {'nom': 'Berthet', 'prenom': 'Alix, Edmond, Fernand'}, {'nom': 'Besset', 'prenom': 'Pierre, Jean'}, {'nom': 'Billat', 'prenom': 'Paul'}, {'nom': 'Billères', 'prenom': 'René, Sylvain, Edouard'}, {'nom': 'Billoux', 'prenom': 'François'}, {'nom': 'Binot', 'prenom': 'Jean'}, {'nom': 'Bissol', 'prenom': 'Léopold'}, {'nom': 'Blondeau ', 'prenom': 'André, Louis'}, {'nom': 'Boccagny', 'prenom': 'Albert, François'}, {'nom': 'Bocoum', 'prenom': 'Barema, Kissourou'}, {'nom': 'Boisseau', 'prenom': 'Roger, Henri, Louis'}, {'nom': 'Bonnaire', 'prenom': 'André, Jean, Marie'}, {'nom': 'Bonnefous', 'prenom': 'Edouard, Henri, Jean'}, {'nom': 'Bonte', 'prenom': 'Florimond, Paul, Denis, Louis, Joseph'}, {'nom': 'Bouhey', 'prenom': 'Jean, Baptiste, Georges'}, {'nom': 'Bouloux', 'prenom': 'Alphonse, Alexandre'}, {'nom': 'Bourbon', 'prenom': 'Henri'}, {'nom': 'Bourgès-Maunoury', 'prenom': 'Maurice, Jean, Marie'}, {'nom': 'Boutard', 'prenom': 'Madeleine, Henriette'}, {'nom': 'Boutavant', 'prenom': 'Rémy, François'}, {'nom': 'Briffod', 'prenom': 'Henri'}, {'nom': 'Brocas', 'prenom': 'Patrice, Pierre, François'}, {'nom': 'Bruelle', 'prenom': 'Louis'}, {'nom': 'Cachin', 'prenom': 'Marcel, Gilles'}, {'nom': 'Cagne', 'prenom': 'Jean'}, {'nom': 'Caillavet', 'prenom': 'Henri, Guy, Pierre, Emile'}, {'nom': 'Calas', 'prenom': 'Raoul, Joseph, Emile'}, {'nom': 'Cance', 'prenom': 'René, Louis'}, {'nom': 'Cartier', 'prenom': 'Marius, Alexandre'}, {'nom': 'Cartier', 'prenom': 'Marcel, Julien, Ursin, René'}, {'nom': 'Casanova', 'prenom': 'Laurent, Antoine'}, {'nom': 'Cassagne', 'prenom': 'René, Jean, Paul'}, {'nom': 'Castera', 'prenom': 'Edmond, Odoïs'}, {'nom': 'Cermolacce', 'prenom': 'Paul, Antoine, Joseph'}, {'nom': 'Césaire', 'prenom': 'Aimé, Fernand, David'}, {'nom': 'Charlot', 'prenom': 'Jean, Constant'}, {'nom': 'Chatelain', 'prenom': 'Roger, Louis, Jean'}, {'nom': 'Chauvet', 'prenom': 'Augustin, Jean, Alexis, Félix'}, {'nom': 'Cheikh', 'prenom': 'Saïd Mohamed Ben Chech Abdallah'}, {'nom': 'Chène', 'prenom': 'André'}, {'nom': 'Cherrier', 'prenom': 'Marcel'}, {'nom': 'Clostermann', 'prenom': 'Pierre, Henri'}, {'nom': 'Cogniot', 'prenom': 'Georges, Auguste, Alexandre'}, {'nom': 'Condat', 'prenom': 'Georges, Mahaman'}, {'nom': 'Conte', 'prenom': 'Arthur, Léon'}, {'nom': 'Coquel', 'prenom': 'Gaston, Hippolyte'}, {'nom': 'Cordillot', 'prenom': 'Jean'}, {'nom': 'Cormier', 'prenom': 'Maurice, François, Marcel, Joseph'}, {'nom': 'Coulibaly', 'prenom': 'Daniel, Ouezzin'}, {'nom': 'Coutant', 'prenom': 'Robert'}, {'nom': 'Cristofol', 'prenom': 'Jean, Joseph, Antoine'}, {'nom': 'Cupfer', 'prenom': 'Guy'}, {'nom': 'Dagain', 'prenom': 'Léon'}, {'nom': 'Daladier', 'prenom': 'Edouard'}, {'nom': 'Darou', 'prenom': 'Marcel'}, {'nom': 'David', 'prenom': 'Marcel'}, {'nom': 'de Baillencourt', 'prenom': 'Albert, Alix, Jacques, Hippolyte, Marie'}, {'nom': 'de Felice', 'prenom': 'Pierre, Henry, Rodolphe'}, {'nom': 'de Lipkowski', ' ...

# %% [markdown]
# Je veux conserver uniquement le premier prénom et le premier nom des députés.

# %%
# Conversion du DataFrame en dictionnaire avec les premiers prénoms et noms
deputes_gauche_dict2 = df_gauche.apply(lambda row: {'prenom': row['prenom'].split(',')[0].strip(),
                                     'nom': row['nom'].split(' ')[0].strip()}, axis=1).tolist()

print(deputes_gauche_dict2)
# Out:
# [{'prenom': 'Paul', 'nom': 'Alduy'}, {'prenom': 'Adrien', 'nom': 'André'}, {'prenom': 'Gustave', 'nom': 'Ansart'}, {'prenom': 'Paul', 'nom': 'Anxionnaz'}, {'prenom': 'René', 'nom': 'Arbeltier'}, {'prenom': 'Franck', 'nom': 'Arnal'}, {'prenom': 'Pascal', 'nom': 'Arrighi'}, {'prenom': 'Achille', 'nom': 'Auban'}, {'prenom': 'Raphaël', 'nom': 'Babet'}, {'prenom': 'Vincent', 'nom': 'Badie'}, {'prenom': 'Robert', 'nom': 'Ballanger'}, {'prenom': 'Marcel', 'nom': 'Barbot'}, {'prenom': 'Joseph dit Virgile', 'nom': 'Barel'}, {'prenom': 'Diawadou', 'nom': 'Barry'}, {'prenom': 'André', 'nom': 'Barthélémy'}, {'prenom': 'Jean', 'nom': 'Bartolini'}, {'prenom': 'Alexandre', 'nom': 'Baurens'}, {'prenom': 'Jean', 'nom': 'Baylet'}, {'prenom': 'Lucien', 'nom': 'Bégouin'}, {'prenom': 'Maurice', 'nom': 'Béné'}, {'prenom': 'Charles', 'nom': 'Benoist'}, {'prenom': 'Alcide', 'nom': 'Benoit'}, {'prenom': 'Alix', 'nom': 'Berthet'}, {'prenom': 'Pierre', 'nom': 'Besset'}, {'prenom': 'Paul', 'nom': 'Billat'}, {'prenom': 'René', 'nom': 'Billères'}, {'prenom': 'François', 'nom': 'Billoux'}, {'prenom': 'Jean', 'nom': 'Binot'}, {'prenom': 'Léopold', 'nom': 'Bissol'}, {'prenom': 'André', 'nom': 'Blondeau'}, {'prenom': 'Albert', 'nom': 'Boccagny'}, {'prenom': 'Barema', 'nom': 'Bocoum'}, {'prenom': 'Roger', 'nom': 'Boisseau'}, {'prenom': 'André', 'nom': 'Bonnaire'}, {'prenom': 'Edouard', 'nom': 'Bonnefous'}, {'prenom': 'Florimond', 'nom': 'Bonte'}, {'prenom': 'Jean', 'nom': 'Bouhey'}, {'prenom': 'Alphonse', 'nom': 'Bouloux'}, {'prenom': 'Henri', 'nom': 'Bourbon'}, {'prenom': 'Maurice', 'nom': 'Bourgès-Maunoury'}, {'prenom': 'Madeleine', 'nom': 'Boutard'}, {'prenom': 'Rémy', 'nom': 'Boutavant'}, {'prenom': 'Henri', 'nom': 'Briffod'}, {'prenom': 'Patrice', 'nom': 'Brocas'}, {'prenom': 'Louis', 'nom': 'Bruelle'}, {'prenom': 'Marcel', 'nom': 'Cachin'}, {'prenom': 'Jean', 'nom': 'Cagne'}, {'prenom': 'Henri', 'nom': 'Caillavet'}, {'prenom': 'Raoul', 'nom': 'Calas'}, {'prenom': 'René', 'nom': 'Cance'}, {'prenom': 'Marius', 'nom': 'Cartier'}, {'prenom': 'Marcel', 'nom': 'Cartier'}, {'prenom': 'Laurent', 'nom': 'Casanova'}, {'prenom': 'René', 'nom': 'Cassagne'}, {'prenom': 'Edmond', 'nom': 'Castera'}, {'prenom': 'Paul', 'nom': 'Cermolacce'}, {'prenom': 'Aimé', 'nom': 'Césaire'}, {'prenom': 'Jean', 'nom': 'Charlot'}, {'prenom': 'Roger', 'nom': 'Chatelain'}, {'prenom': 'Augustin', 'nom': 'Chauvet'}, {'prenom': 'Saïd Mohamed Ben Chech Abdallah', 'nom': 'Cheikh'}, {'prenom': 'André', 'nom': 'Chène'}, {'prenom': 'Marcel', 'nom': 'Cherrier'}, {'prenom': 'Pierre', 'nom': 'Clostermann'}, {'prenom': 'Georges', 'nom': 'Cogniot'}, {'prenom': 'Georges', 'nom': 'Condat'}, {'prenom': 'Arthur', 'nom': 'Conte'}, {'prenom': 'Gaston', 'nom': 'Coquel'}, {'prenom': 'Jean', 'nom': 'Cordillot'}, {'prenom': 'Maurice', 'nom': 'Cormier'}, {'prenom': 'Daniel', 'nom': 'Coulibaly'}, {'prenom': 'Robert', 'nom': 'Coutant'}, {'prenom': 'Jean', 'nom': 'Cristofol'}, {'prenom': 'Guy', 'nom': 'Cupfer'}, {'prenom': 'Léon', 'nom': 'Dagain'}, {'prenom': 'Edouard', 'nom': 'Daladier'}, {'prenom': 'Marcel', 'nom': 'Darou'}, {'prenom': 'Marcel', 'nom': 'David'}, {'prenom': 'Albert', 'nom': 'de'}, {'prenom': 'Pierre', 'nom': 'de'}, {'prenom': 'Jean', 'nom': 'de'}, {'prenom': 'Vincent', 'nom': 'de'}, {'prenom': 'Gaston', 'nom': 'Defferre'}, {'prenom': 'Auguste', 'nom': 'Defrance'}, {'prenom': 'Lucien', 'nom': 'Degoutte'}, {'prenom': 'Céline', 'nom': 'Degrond'}, {'prenom': 'Maurice', 'nom': 'Deixonne'}, {'prenom': 'René', 'nom': 'Dejean'}, {'prenom': 'Camille', 'nom': 'Delabre'}, {'prenom': 'Antoine', 'nom': 'Demusois'}, {'prenom': 'Alphonse', 'nom': 'Denis'}, {'prenom': 'Albert', 'nom': 'Denvers'}, {'prenom': 'Edouard', 'nom': 'Depreux'}, {'prenom': 'Edmond', 'nom': 'Desouches'}, {'prenom': 'Guy', 'nom': 'Desson'}, {'prenom': 'Paul', 'nom': 'Devinat'}, {'prenom': 'Tarsyle', 'nom': 'Dewasmes'}, {'prenom': 'Saïfoulaye', 'nom': 'Diallo'}, {'prenom': 'Jean', 'nom': 'Diat'}, {'prenom': 'Hamadoun', 'nom': 'Dicko'}, {'pre ...

# %% [markdown]
# Cela n'allait pas, car certains députés ont un nom à plusieurs mots, notamment ceux qui ont une particule (de) ou originaires de Bretagne (le)

# %%
def prepare_nom(nom):
    mots = nom.split(' ')
    # Si le premier mot du nom est "Le" ou "de", retournez le premier et le deuxième mot
    if mots[0] in ["Le", "de"]:
        return " ".join(mots[:2])
    return mots[0]

deputes_gauche_dict3 = df_gauche.apply(lambda row: {'prenom': row['prenom'].split(',')[0].strip(),
                                                    'nom': prepare_nom(row['nom'])}, axis=1).tolist()

print(deputes_gauche_dict3)
# Out:
# [{'prenom': 'Paul', 'nom': 'Alduy'}, {'prenom': 'Adrien', 'nom': 'André'}, {'prenom': 'Gustave', 'nom': 'Ansart'}, {'prenom': 'Paul', 'nom': 'Anxionnaz'}, {'prenom': 'René', 'nom': 'Arbeltier'}, {'prenom': 'Franck', 'nom': 'Arnal'}, {'prenom': 'Pascal', 'nom': 'Arrighi'}, {'prenom': 'Achille', 'nom': 'Auban'}, {'prenom': 'Raphaël', 'nom': 'Babet'}, {'prenom': 'Vincent', 'nom': 'Badie'}, {'prenom': 'Robert', 'nom': 'Ballanger'}, {'prenom': 'Marcel', 'nom': 'Barbot'}, {'prenom': 'Joseph dit Virgile', 'nom': 'Barel'}, {'prenom': 'Diawadou', 'nom': 'Barry'}, {'prenom': 'André', 'nom': 'Barthélémy'}, {'prenom': 'Jean', 'nom': 'Bartolini'}, {'prenom': 'Alexandre', 'nom': 'Baurens'}, {'prenom': 'Jean', 'nom': 'Baylet'}, {'prenom': 'Lucien', 'nom': 'Bégouin'}, {'prenom': 'Maurice', 'nom': 'Béné'}, {'prenom': 'Charles', 'nom': 'Benoist'}, {'prenom': 'Alcide', 'nom': 'Benoit'}, {'prenom': 'Alix', 'nom': 'Berthet'}, {'prenom': 'Pierre', 'nom': 'Besset'}, {'prenom': 'Paul', 'nom': 'Billat'}, {'prenom': 'René', 'nom': 'Billères'}, {'prenom': 'François', 'nom': 'Billoux'}, {'prenom': 'Jean', 'nom': 'Binot'}, {'prenom': 'Léopold', 'nom': 'Bissol'}, {'prenom': 'André', 'nom': 'Blondeau'}, {'prenom': 'Albert', 'nom': 'Boccagny'}, {'prenom': 'Barema', 'nom': 'Bocoum'}, {'prenom': 'Roger', 'nom': 'Boisseau'}, {'prenom': 'André', 'nom': 'Bonnaire'}, {'prenom': 'Edouard', 'nom': 'Bonnefous'}, {'prenom': 'Florimond', 'nom': 'Bonte'}, {'prenom': 'Jean', 'nom': 'Bouhey'}, {'prenom': 'Alphonse', 'nom': 'Bouloux'}, {'prenom': 'Henri', 'nom': 'Bourbon'}, {'prenom': 'Maurice', 'nom': 'Bourgès-Maunoury'}, {'prenom': 'Madeleine', 'nom': 'Boutard'}, {'prenom': 'Rémy', 'nom': 'Boutavant'}, {'prenom': 'Henri', 'nom': 'Briffod'}, {'prenom': 'Patrice', 'nom': 'Brocas'}, {'prenom': 'Louis', 'nom': 'Bruelle'}, {'prenom': 'Marcel', 'nom': 'Cachin'}, {'prenom': 'Jean', 'nom': 'Cagne'}, {'prenom': 'Henri', 'nom': 'Caillavet'}, {'prenom': 'Raoul', 'nom': 'Calas'}, {'prenom': 'René', 'nom': 'Cance'}, {'prenom': 'Marius', 'nom': 'Cartier'}, {'prenom': 'Marcel', 'nom': 'Cartier'}, {'prenom': 'Laurent', 'nom': 'Casanova'}, {'prenom': 'René', 'nom': 'Cassagne'}, {'prenom': 'Edmond', 'nom': 'Castera'}, {'prenom': 'Paul', 'nom': 'Cermolacce'}, {'prenom': 'Aimé', 'nom': 'Césaire'}, {'prenom': 'Jean', 'nom': 'Charlot'}, {'prenom': 'Roger', 'nom': 'Chatelain'}, {'prenom': 'Augustin', 'nom': 'Chauvet'}, {'prenom': 'Saïd Mohamed Ben Chech Abdallah', 'nom': 'Cheikh'}, {'prenom': 'André', 'nom': 'Chène'}, {'prenom': 'Marcel', 'nom': 'Cherrier'}, {'prenom': 'Pierre', 'nom': 'Clostermann'}, {'prenom': 'Georges', 'nom': 'Cogniot'}, {'prenom': 'Georges', 'nom': 'Condat'}, {'prenom': 'Arthur', 'nom': 'Conte'}, {'prenom': 'Gaston', 'nom': 'Coquel'}, {'prenom': 'Jean', 'nom': 'Cordillot'}, {'prenom': 'Maurice', 'nom': 'Cormier'}, {'prenom': 'Daniel', 'nom': 'Coulibaly'}, {'prenom': 'Robert', 'nom': 'Coutant'}, {'prenom': 'Jean', 'nom': 'Cristofol'}, {'prenom': 'Guy', 'nom': 'Cupfer'}, {'prenom': 'Léon', 'nom': 'Dagain'}, {'prenom': 'Edouard', 'nom': 'Daladier'}, {'prenom': 'Marcel', 'nom': 'Darou'}, {'prenom': 'Marcel', 'nom': 'David'}, {'prenom': 'Albert', 'nom': 'de Baillencourt'}, {'prenom': 'Pierre', 'nom': 'de Felice'}, {'prenom': 'Jean', 'nom': 'de Lipkowski'}, {'prenom': 'Vincent', 'nom': 'de Moro-Giafferri'}, {'prenom': 'Gaston', 'nom': 'Defferre'}, {'prenom': 'Auguste', 'nom': 'Defrance'}, {'prenom': 'Lucien', 'nom': 'Degoutte'}, {'prenom': 'Céline', 'nom': 'Degrond'}, {'prenom': 'Maurice', 'nom': 'Deixonne'}, {'prenom': 'René', 'nom': 'Dejean'}, {'prenom': 'Camille', 'nom': 'Delabre'}, {'prenom': 'Antoine', 'nom': 'Demusois'}, {'prenom': 'Alphonse', 'nom': 'Denis'}, {'prenom': 'Albert', 'nom': 'Denvers'}, {'prenom': 'Edouard', 'nom': 'Depreux'}, {'prenom': 'Edmond', 'nom': 'Desouches'}, {'prenom': 'Guy', 'nom': 'Desson'}, {'prenom': 'Paul', 'nom': 'Devinat'}, {'prenom': 'Tarsyle', 'nom': 'Dewasmes'}, {'prenom': 'Saïfoulaye', 'nom': 'Diallo'}, {'prenom': 'Jean', 'nom': 'Diat'},  ...

# %%
df_gauche_corrigé = pd.DataFrame(deputes_gauche_dict3)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 50)
print(df_gauche_corrigé) ## Reste Raymond dit Gérard
# Out:
#                               prenom                 nom
# 0                               Paul               Alduy
# 1                             Adrien               André
# 2                            Gustave              Ansart
# 3                               Paul           Anxionnaz
# 4                               René           Arbeltier
# 5                             Franck               Arnal
# 6                             Pascal             Arrighi
# 7                            Achille               Auban
# 8                            Raphaël               Babet
# 9                            Vincent               Badie
# 10                            Robert           Ballanger
# 11                            Marcel              Barbot
# 12                Joseph dit Virgile               Barel
# 13                          Diawadou               Barry
# 14                             André          Barthélémy
# 15                              Jean           Bartolini
# 16                         Alexandre             Baurens
# 17                              Jean              Baylet
# 18                            Lucien             Bégouin
# 19                           Maurice                Béné
# 20                           Charles             Benoist
# 21                            Alcide              Benoit
# 22                              Alix             Berthet
# 23                            Pierre              Besset
# 24                              Paul              Billat
# 25                              René            Billères
# 26                          François             Billoux
# 27                              Jean               Binot
# 28                           Léopold              Bissol
# 29                             André            Blondeau
# 30                            Albert            Boccagny
# 31                            Barema              Bocoum
# 32                             Roger            Boisseau
# 33                             André            Bonnaire
# 34                           Edouard           Bonnefous
# 35                         Florimond               Bonte
# 36                              Jean              Bouhey
# 37                          Alphonse             Bouloux
# 38                             Henri             Bourbon
# 39                           Maurice    Bourgès-Maunoury
# 40                         Madeleine             Boutard
# 41                              Rémy           Boutavant
# 42                             Henri             Briffod
# 43                           Patrice              Brocas
# 44                             Louis             Bruelle
# 45                            Marcel              Cachin
# 46                              Jean               Cagne
# 47                             Henri           Caillavet
# 48                             Raoul               Calas
# 49                              René               Cance
# 50                            Marius             Cartier
# 51                            Marcel             Cartier
# 52                           Laurent            Casanova
# 53                              René            Cassagne
# 54                            Edmond             Castera
# 55                              Paul          Cermolacce
# 56                              Aimé             Césaire
# 57                              Jean             Charlot
# 58                             Roger           Chatelain
# 59                          Augustin             Chauvet
# 60   Saïd Mohamed Ben Chech Abdallah              Cheikh
# 61                             André               Chène
# 62                            Marcel            Cherrier
# 63                            Pierre         Clostermann
# 64                           Georges             Cogniot
# 65                           Georges              Condat
# 66                            Arthur               Conte
# 67                            Gaston              Coquel
# 68                              Jean           Cordillot
# 69                           Maurice             Cormier
# 70                            Daniel           Coulibaly
# 71                            Robert             Coutant
# 72                              Jean           Cristofol
# 73                               Guy              Cupfer
# 74                              Léon              Dagain
# 75                           Edouard            Daladier
# 76                            Marcel               Darou
# 77                            Marcel               David
# 78                            Albert     de Baillencourt
# 79                            Pierre           de Felice
# 80                              Jean        de Lipkowski
# 81                           Vincent   de Moro-Giafferri
# 82                            Gaston            Defferre
# 83                           Auguste            Defrance
# 84                            Lucien            Degoutte
# 85                            Céline             Degrond
# 86                           Maurice            Deixonne
# 87                              René              Dejean
# 88                           Camille             Delabre
# 89                           Antoine            Demusois
# 90                          Alphonse               Denis
# 91                            Albert             Denvers
# 92                           Edouard             Depreux
# 93                            Edmond           Desouches
# 94                               Guy              Desson
# 95                              Paul             Devinat
# 96                           Tarsyle            Dewasmes
# 97                        Saïfoulaye              Diallo
# 98                              Jean                Diat
# 99                          Hamadoun               Dicko
# 100                           Pierre               Doize
# 101                           Pierre          Doutrellot
# 102                            Louis              Dubois
# 103                          Jacques              Duclos
# 104                        Hippolyte               Ducos
# 105                            André              Dufour
# 106                           Roland               Dumas
# 107                          Jeannil           Dumortier
# 108                            Louis              Dupont
# 109               Raymond dit Gérard              Duprat
# 110                             Marc               Dupuy
# 111                             Jean             Durroux
# 112                            Roger              Duveau
# 113                          Eugénie           Duvernois
# 114                           Yvonne             Estachy
# 115                            Louis              Eudier
# 116                             Just              Évrard
# 117                          Jacques         Faggianelli
# 118                          Etienne               Fajon
# 119                            Roger              Faraud
# 120                          Maurice               Faure
# 121                             Jean      Félix-Tchicaya
# 122                           Eugène             Fourvel
# 123                            Marie     François-Bénard
# 124                            Roger             Gaborit
# 125                          Etienne            Gagnaire
# 126                            Félix            Gaillard
# 127                        Emilienne            Galicier
# 128                           Joseph               Garat
# 129                            Roger             Garaudy
# 130                            Louis             Garnier
# 131                            André             Gautier
# 132                           Albert              Gazier
# 133                          Raymond              Gernez
# 134                         François            Giacobbi
# 135                            Rosan              Girard
# 136                           Pierre            Girardot
# 137                          Georges              Gosnat
# 138                             Jean             Goudoux
# 139                            Félix               Gouin
# 140                           Robert             Gourdon
# 141                           Gilles              Gozard
# 142                            Elise              Grappe
# 143                           Gilles           Gravoille
# 144                          Fernand             Grenier
# 145                             Rose              Guérin
# 146                          Germain             Guibert
# 147                          Georges              Guille
# 148                           Marcel            Guislain
# 149                             Jean             Guitton
# 150                     Jean-Raymond               Guyon
# 151                          Raymond               Guyot
# 152                            Diori              Hamani
# 153                           Marcel               Hamon
# 154                          Olivier               Harty
# 155                            Henri         Henneguelle
# 156                          Charles               Hernu
# 157                          Edouard             Herriot
# 158                           Robert             Hersant
# 159                             Jean          Houdremont
# 160                            Félix    Houphouët-Boigny
# 161                             Léon           Hovnanian
# 162                            Emile              Hugues
# 163                            André              Hugues
# 164                           Gérard              Jaquet
# 165                          Bernard           Jourd'Huy
# 166                           Pierre                Juge
# 167                           Gaston              Julian
# 168                          Georges        Juskiewenski
# 169                              Max             Juvénal
# 170                           Modibo               Keita
# 171                          Mamadou              Konaté
# 172                          Maurice   Kriegel-Valrimont
# 173                           Robert             Lacoste
# 174                            Henri            Laforest
# 175                          Charles      Lamarque-Cando
# 176                           Lucien             Lambert
# 177                             René               Lamps
# 178                   Pierre-Olivier               Lapie
# 179                           Pierre             Lareppe
# 180                             Tony               Larue
# 181                             Jean             Le Bail
# 182                        Guillaume           Le Caroff
# 183                            André            Le Floch
# 184                           Alexis            Le Strat
# 185                            André          Le Troquer
# 186                           Claude            Leclercq
# 187                         Constant             Lecoeur
# 188                          Francis           Leenhardt
# 189                          Raymond             Lefranc
# 190                          Fernand           Legagneux
# 191                              Max             Lejeune
# 192                           Rachel           Lempereur
# 193                            André           Lenormand
# 194                           Roland               Leroy
# 195                             Jean             Lespiau
# 196                          Léandre           Letoquart
# 197                           Marcel           Levindrey
# 198                          Gabriel             Lisette
# 199                             Jean              Llante
# 200                           Kléber             Loustau
# 201                           Adrien              Mabrut
# 202                           Pierre              Mailhé
# 203                           Alfred  Malleret-Joinville
# 204                           Robert             Manceau
# 205                            André              Mancey
# 206                            Hervé                 Mao
# 207                          Charles         Margueritte
# 208                             René              Mariat
# 209                            André               Marie
# 210                          Fernand               Marin
# 211                            André           Maroselli
# 212                          Georges             Marrane
# 213                            Henri              Martel
# 214                          Gilbert              Martin
# 215                        Madeleine              Marzin
# 216                             Jean               Masse
# 217                             Jean              Masson
# 218                           Albert               Maton
# 219                           Daniel               Mayer
# 220                          Antoine              Mazier
# 221                          Fernand              Mazuez
# 222                      André-Marie               Mbida
# 223                           Pierre              Mendès
# 224                            André             Mercier
# 225                           Marcel           Mérigonde
# 226                        Toussaint               Merle
# 227                           Pierre             Métayer
# 228                             Jean             Meunier
# 229                          Maurice              Michel
# 230                           Lucien               Midol
# 231                             Jean              Minjoz
# 232                         François          Mitterrand
# 233                            Jules                Moch
# 234                              Guy              Mollet
# 235                          Raymond              Mondon
# 236                           Pierre         Monnerville
# 237                             Jean            Montalat
# 238                           Eugène              Montel
# 239                           Albert                Mora
# 240                            Roger              Morève
# 241                            André              Morice
# 242                           Adrien              Mouton
# 243                          Auguste               Mudry
# 244                           Arthur            Musmeaux
# 245                    Marcel-Edmond            Naegelen
# 246                           Pierre              Naudet
# 247                            Jules              Ninine
# 248                           Marcel                Noël
# 249                           Arthur            Notebart
# 250                             René               Pagès
# 251                             Jean             Palméro
# 252                           Claude              Panier
# 253                            André          Parmentier
# 254                          Gabriel                Paul
# 255                          Bernard             Paumier
# 256                           Marcel            Pélissou
# 257                         Alphonse              Penven
# 258                          Maurice              Perche
# 259                         Mathilde                Péri
# 260                             Yves               Péron
# 261                            André            Pierrard
# 262                          Jacques              Piette
# 263                        Christian              Pineau
# 264                          Georges               Pirot
# 265                           Roland           Plaisance
# 266                             René              Pleven
# 267                            Henri           Pourtalet
# 268                           Pierre           Pranchère
# 269                           Tanguy             Prigent
# 270                        Jeannette                Prin
# 271                             Jean            Pronteau
# 272                            Louis                Prot
# 273                           Victor               Provo
# 274                            Henri            Queuille
# 275                            Maria              Rabaté
# 276                             Paul            Ramadier
# 277                           Arthur             Ramette
# 278                          Edouard             Ramonet
# 279                            Roger              Ranoux
# 280                             René            Regaudie
# 281                           Adrien              Renard
# 282                            Renée             Reyraud
# 283                             Jean                Rieu
# 284                          Germain             Rincent
# 285                         Gilberte                Roca
# 286                          Waldeck              Rochet
# 287                          Jacques             Rolland
# 288                            Félix           Roquefort
# 289                            Roger            Roucaute
# 290                          Gabriel            Roucaute
# 291                          Charles                Ruff
# 292                           Hubert               Ruffe
# 293                         Marcelle              Rumeau
# 294                             Léon              Sagnol
# 295                            Raoul               Sauer
# 296                            André              Savard
# 297                            Alain              Savary
# 298                           Pierre             Ségelle
# 299                        Fily-Dabo             Sissoko
# 300                           Michel              Soulié
# 301                           Pierre             Souquès
# 302                            André               Soury
# 303                            Henri             Thamier
# 304                           Marcel             Thibaud
# 305                           Eugène              Thomas
# 306                         Ennemond              Thoral
# 307                          Maurice              Thorez
# 308                          Camille              Titeux
# 309                            Marie       Tony-Révillon
# 310                            Sékou               Touré
# 311                            André              Tourné
# 312                          Auguste            Tourtaud
# 313                          Raphaël          Trémouilhe
# 314                             Jean             Tricart
# 315                        Philibert           Tsiranana
# 316                             René                 Tys
# 317                     Marie-Claude  Vaillant-Couturier
# 318                          Camille              Vallin
# 319                          Francis                Vals
# 320                            Henri            Védrines
# 321                           Robert             Verdier
# 322                             Paul              Vergès
# 323                        Jeannette   Vermeersch-Thorez
# 324                         Emmanuel       Véry-Hermence
# 325                           Pierre   Villon-Ginsburger
# 326                            André            Vuillien

# %%
for dict in deputes_gauche_dict3:
    if dict["prenom"] == "Raymond dit Gérard":
        dict["prenom"] = "Gérard"

# %%
df_gauche_corrigé2 = pd.DataFrame(deputes_gauche_dict3)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 50)
print(df_gauche_corrigé2)
# Out:
#                               prenom                 nom
# 0                               Paul               Alduy
# 1                             Adrien               André
# 2                            Gustave              Ansart
# 3                               Paul           Anxionnaz
# 4                               René           Arbeltier
# 5                             Franck               Arnal
# 6                             Pascal             Arrighi
# 7                            Achille               Auban
# 8                            Raphaël               Babet
# 9                            Vincent               Badie
# 10                            Robert           Ballanger
# 11                            Marcel              Barbot
# 12                Joseph dit Virgile               Barel
# 13                          Diawadou               Barry
# 14                             André          Barthélémy
# 15                              Jean           Bartolini
# 16                         Alexandre             Baurens
# 17                              Jean              Baylet
# 18                            Lucien             Bégouin
# 19                           Maurice                Béné
# 20                           Charles             Benoist
# 21                            Alcide              Benoit
# 22                              Alix             Berthet
# 23                            Pierre              Besset
# 24                              Paul              Billat
# 25                              René            Billères
# 26                          François             Billoux
# 27                              Jean               Binot
# 28                           Léopold              Bissol
# 29                             André            Blondeau
# 30                            Albert            Boccagny
# 31                            Barema              Bocoum
# 32                             Roger            Boisseau
# 33                             André            Bonnaire
# 34                           Edouard           Bonnefous
# 35                         Florimond               Bonte
# 36                              Jean              Bouhey
# 37                          Alphonse             Bouloux
# 38                             Henri             Bourbon
# 39                           Maurice    Bourgès-Maunoury
# 40                         Madeleine             Boutard
# 41                              Rémy           Boutavant
# 42                             Henri             Briffod
# 43                           Patrice              Brocas
# 44                             Louis             Bruelle
# 45                            Marcel              Cachin
# 46                              Jean               Cagne
# 47                             Henri           Caillavet
# 48                             Raoul               Calas
# 49                              René               Cance
# 50                            Marius             Cartier
# 51                            Marcel             Cartier
# 52                           Laurent            Casanova
# 53                              René            Cassagne
# 54                            Edmond             Castera
# 55                              Paul          Cermolacce
# 56                              Aimé             Césaire
# 57                              Jean             Charlot
# 58                             Roger           Chatelain
# 59                          Augustin             Chauvet
# 60   Saïd Mohamed Ben Chech Abdallah              Cheikh
# 61                             André               Chène
# 62                            Marcel            Cherrier
# 63                            Pierre         Clostermann
# 64                           Georges             Cogniot
# 65                           Georges              Condat
# 66                            Arthur               Conte
# 67                            Gaston              Coquel
# 68                              Jean           Cordillot
# 69                           Maurice             Cormier
# 70                            Daniel           Coulibaly
# 71                            Robert             Coutant
# 72                              Jean           Cristofol
# 73                               Guy              Cupfer
# 74                              Léon              Dagain
# 75                           Edouard            Daladier
# 76                            Marcel               Darou
# 77                            Marcel               David
# 78                            Albert     de Baillencourt
# 79                            Pierre           de Felice
# 80                              Jean        de Lipkowski
# 81                           Vincent   de Moro-Giafferri
# 82                            Gaston            Defferre
# 83                           Auguste            Defrance
# 84                            Lucien            Degoutte
# 85                            Céline             Degrond
# 86                           Maurice            Deixonne
# 87                              René              Dejean
# 88                           Camille             Delabre
# 89                           Antoine            Demusois
# 90                          Alphonse               Denis
# 91                            Albert             Denvers
# 92                           Edouard             Depreux
# 93                            Edmond           Desouches
# 94                               Guy              Desson
# 95                              Paul             Devinat
# 96                           Tarsyle            Dewasmes
# 97                        Saïfoulaye              Diallo
# 98                              Jean                Diat
# 99                          Hamadoun               Dicko
# 100                           Pierre               Doize
# 101                           Pierre          Doutrellot
# 102                            Louis              Dubois
# 103                          Jacques              Duclos
# 104                        Hippolyte               Ducos
# 105                            André              Dufour
# 106                           Roland               Dumas
# 107                          Jeannil           Dumortier
# 108                            Louis              Dupont
# 109                           Gérard              Duprat
# 110                             Marc               Dupuy
# 111                             Jean             Durroux
# 112                            Roger              Duveau
# 113                          Eugénie           Duvernois
# 114                           Yvonne             Estachy
# 115                            Louis              Eudier
# 116                             Just              Évrard
# 117                          Jacques         Faggianelli
# 118                          Etienne               Fajon
# 119                            Roger              Faraud
# 120                          Maurice               Faure
# 121                             Jean      Félix-Tchicaya
# 122                           Eugène             Fourvel
# 123                            Marie     François-Bénard
# 124                            Roger             Gaborit
# 125                          Etienne            Gagnaire
# 126                            Félix            Gaillard
# 127                        Emilienne            Galicier
# 128                           Joseph               Garat
# 129                            Roger             Garaudy
# 130                            Louis             Garnier
# 131                            André             Gautier
# 132                           Albert              Gazier
# 133                          Raymond              Gernez
# 134                         François            Giacobbi
# 135                            Rosan              Girard
# 136                           Pierre            Girardot
# 137                          Georges              Gosnat
# 138                             Jean             Goudoux
# 139                            Félix               Gouin
# 140                           Robert             Gourdon
# 141                           Gilles              Gozard
# 142                            Elise              Grappe
# 143                           Gilles           Gravoille
# 144                          Fernand             Grenier
# 145                             Rose              Guérin
# 146                          Germain             Guibert
# 147                          Georges              Guille
# 148                           Marcel            Guislain
# 149                             Jean             Guitton
# 150                     Jean-Raymond               Guyon
# 151                          Raymond               Guyot
# 152                            Diori              Hamani
# 153                           Marcel               Hamon
# 154                          Olivier               Harty
# 155                            Henri         Henneguelle
# 156                          Charles               Hernu
# 157                          Edouard             Herriot
# 158                           Robert             Hersant
# 159                             Jean          Houdremont
# 160                            Félix    Houphouët-Boigny
# 161                             Léon           Hovnanian
# 162                            Emile              Hugues
# 163                            André              Hugues
# 164                           Gérard              Jaquet
# 165                          Bernard           Jourd'Huy
# 166                           Pierre                Juge
# 167                           Gaston              Julian
# 168                          Georges        Juskiewenski
# 169                              Max             Juvénal
# 170                           Modibo               Keita
# 171                          Mamadou              Konaté
# 172                          Maurice   Kriegel-Valrimont
# 173                           Robert             Lacoste
# 174                            Henri            Laforest
# 175                          Charles      Lamarque-Cando
# 176                           Lucien             Lambert
# 177                             René               Lamps
# 178                   Pierre-Olivier               Lapie
# 179                           Pierre             Lareppe
# 180                             Tony               Larue
# 181                             Jean             Le Bail
# 182                        Guillaume           Le Caroff
# 183                            André            Le Floch
# 184                           Alexis            Le Strat
# 185                            André          Le Troquer
# 186                           Claude            Leclercq
# 187                         Constant             Lecoeur
# 188                          Francis           Leenhardt
# 189                          Raymond             Lefranc
# 190                          Fernand           Legagneux
# 191                              Max             Lejeune
# 192                           Rachel           Lempereur
# 193                            André           Lenormand
# 194                           Roland               Leroy
# 195                             Jean             Lespiau
# 196                          Léandre           Letoquart
# 197                           Marcel           Levindrey
# 198                          Gabriel             Lisette
# 199                             Jean              Llante
# 200                           Kléber             Loustau
# 201                           Adrien              Mabrut
# 202                           Pierre              Mailhé
# 203                           Alfred  Malleret-Joinville
# 204                           Robert             Manceau
# 205                            André              Mancey
# 206                            Hervé                 Mao
# 207                          Charles         Margueritte
# 208                             René              Mariat
# 209                            André               Marie
# 210                          Fernand               Marin
# 211                            André           Maroselli
# 212                          Georges             Marrane
# 213                            Henri              Martel
# 214                          Gilbert              Martin
# 215                        Madeleine              Marzin
# 216                             Jean               Masse
# 217                             Jean              Masson
# 218                           Albert               Maton
# 219                           Daniel               Mayer
# 220                          Antoine              Mazier
# 221                          Fernand              Mazuez
# 222                      André-Marie               Mbida
# 223                           Pierre              Mendès
# 224                            André             Mercier
# 225                           Marcel           Mérigonde
# 226                        Toussaint               Merle
# 227                           Pierre             Métayer
# 228                             Jean             Meunier
# 229                          Maurice              Michel
# 230                           Lucien               Midol
# 231                             Jean              Minjoz
# 232                         François          Mitterrand
# 233                            Jules                Moch
# 234                              Guy              Mollet
# 235                          Raymond              Mondon
# 236                           Pierre         Monnerville
# 237                             Jean            Montalat
# 238                           Eugène              Montel
# 239                           Albert                Mora
# 240                            Roger              Morève
# 241                            André              Morice
# 242                           Adrien              Mouton
# 243                          Auguste               Mudry
# 244                           Arthur            Musmeaux
# 245                    Marcel-Edmond            Naegelen
# 246                           Pierre              Naudet
# 247                            Jules              Ninine
# 248                           Marcel                Noël
# 249                           Arthur            Notebart
# 250                             René               Pagès
# 251                             Jean             Palméro
# 252                           Claude              Panier
# 253                            André          Parmentier
# 254                          Gabriel                Paul
# 255                          Bernard             Paumier
# 256                           Marcel            Pélissou
# 257                         Alphonse              Penven
# 258                          Maurice              Perche
# 259                         Mathilde                Péri
# 260                             Yves               Péron
# 261                            André            Pierrard
# 262                          Jacques              Piette
# 263                        Christian              Pineau
# 264                          Georges               Pirot
# 265                           Roland           Plaisance
# 266                             René              Pleven
# 267                            Henri           Pourtalet
# 268                           Pierre           Pranchère
# 269                           Tanguy             Prigent
# 270                        Jeannette                Prin
# 271                             Jean            Pronteau
# 272                            Louis                Prot
# 273                           Victor               Provo
# 274                            Henri            Queuille
# 275                            Maria              Rabaté
# 276                             Paul            Ramadier
# 277                           Arthur             Ramette
# 278                          Edouard             Ramonet
# 279                            Roger              Ranoux
# 280                             René            Regaudie
# 281                           Adrien              Renard
# 282                            Renée             Reyraud
# 283                             Jean                Rieu
# 284                          Germain             Rincent
# 285                         Gilberte                Roca
# 286                          Waldeck              Rochet
# 287                          Jacques             Rolland
# 288                            Félix           Roquefort
# 289                            Roger            Roucaute
# 290                          Gabriel            Roucaute
# 291                          Charles                Ruff
# 292                           Hubert               Ruffe
# 293                         Marcelle              Rumeau
# 294                             Léon              Sagnol
# 295                            Raoul               Sauer
# 296                            André              Savard
# 297                            Alain              Savary
# 298                           Pierre             Ségelle
# 299                        Fily-Dabo             Sissoko
# 300                           Michel              Soulié
# 301                           Pierre             Souquès
# 302                            André               Soury
# 303                            Henri             Thamier
# 304                           Marcel             Thibaud
# 305                           Eugène              Thomas
# 306                         Ennemond              Thoral
# 307                          Maurice              Thorez
# 308                          Camille              Titeux
# 309                            Marie       Tony-Révillon
# 310                            Sékou               Touré
# 311                            André              Tourné
# 312                          Auguste            Tourtaud
# 313                          Raphaël          Trémouilhe
# 314                             Jean             Tricart
# 315                        Philibert           Tsiranana
# 316                             René                 Tys
# 317                     Marie-Claude  Vaillant-Couturier
# 318                          Camille              Vallin
# 319                          Francis                Vals
# 320                            Henri            Védrines
# 321                           Robert             Verdier
# 322                             Paul              Vergès
# 323                        Jeannette   Vermeersch-Thorez
# 324                         Emmanuel       Véry-Hermence
# 325                           Pierre   Villon-Ginsburger
# 326                            André            Vuillien

# %% [markdown]
# #### Conversion des pdf en txt

# %%
#pip install pdfminer.six

# %% [markdown]
# #### Extraction pdf 1958_1

# %%
import os
from pdfminer.high_level import extract_text

def convert_pdf_to_txt(folder_path, output_filename):
    output_file = open(output_filename, "w")
    for foldername, subfolders, filenames in os.walk(folder_path):
        for filename in filenames:
            if filename.endswith('.pdf'):
                path_to_pdf = os.path.join(foldername, filename)
                text = extract_text(path_to_pdf)
                output_file.write(text + "\n")
    output_file.close()

convert_pdf_to_txt('/Volumes/Elements/JO_débats_1956-1958/JO_Débats_1958_1/', 'débats1958_1.txt') 
# on appelle un répertoire de départ et un fichier d'arrivée

# %%
deputes_gauche_dict3
# Out:
# [{'prenom': 'Paul', 'nom': 'Alduy'},
#  {'prenom': 'Adrien', 'nom': 'André'},
#  {'prenom': 'Gustave', 'nom': 'Ansart'},
#  {'prenom': 'Paul', 'nom': 'Anxionnaz'},
#  {'prenom': 'René', 'nom': 'Arbeltier'},
#  {'prenom': 'Franck', 'nom': 'Arnal'},
#  {'prenom': 'Pascal', 'nom': 'Arrighi'},
#  {'prenom': 'Achille', 'nom': 'Auban'},
#  {'prenom': 'Raphaël', 'nom': 'Babet'},
#  {'prenom': 'Vincent', 'nom': 'Badie'},
#  {'prenom': 'Robert', 'nom': 'Ballanger'},
#  {'prenom': 'Marcel', 'nom': 'Barbot'},
#  {'prenom': 'Joseph dit Virgile', 'nom': 'Barel'},
#  {'prenom': 'Diawadou', 'nom': 'Barry'},
#  {'prenom': 'André', 'nom': 'Barthélémy'},
#  {'prenom': 'Jean', 'nom': 'Bartolini'},
#  {'prenom': 'Alexandre', 'nom': 'Baurens'},
#  {'prenom': 'Jean', 'nom': 'Baylet'},
#  {'prenom': 'Lucien', 'nom': 'Bégouin'},
#  {'prenom': 'Maurice', 'nom': 'Béné'},
#  {'prenom': 'Charles', 'nom': 'Benoist'},
#  {'prenom': 'Alcide', 'nom': 'Benoit'},
#  {'prenom': 'Alix', 'nom': 'Berthet'},
#  {'prenom': 'Pierre', 'nom': 'Besset'},
#  {'prenom': 'Paul', 'nom': 'Billat'},
#  {'prenom': 'René', 'nom': 'Billères'},
#  {'prenom': 'François', 'nom': 'Billoux'},
#  {'prenom': 'Jean', 'nom': 'Binot'},
#  {'prenom': 'Léopold', 'nom': 'Bissol'},
#  {'prenom': 'André', 'nom': 'Blondeau'},
#  {'prenom': 'Albert', 'nom': 'Boccagny'},
#  {'prenom': 'Barema', 'nom': 'Bocoum'},
#  {'prenom': 'Roger', 'nom': 'Boisseau'},
#  {'prenom': 'André', 'nom': 'Bonnaire'},
#  {'prenom': 'Edouard', 'nom': 'Bonnefous'},
#  {'prenom': 'Florimond', 'nom': 'Bonte'},
#  {'prenom': 'Jean', 'nom': 'Bouhey'},
#  {'prenom': 'Alphonse', 'nom': 'Bouloux'},
#  {'prenom': 'Henri', 'nom': 'Bourbon'},
#  {'prenom': 'Maurice', 'nom': 'Bourgès-Maunoury'},
#  {'prenom': 'Madeleine', 'nom': 'Boutard'},
#  {'prenom': 'Rémy', 'nom': 'Boutavant'},
#  {'prenom': 'Henri', 'nom': 'Briffod'},
#  {'prenom': 'Patrice', 'nom': 'Brocas'},
#  {'prenom': 'Louis', 'nom': 'Bruelle'},
#  {'prenom': 'Marcel', 'nom': 'Cachin'},
#  {'prenom': 'Jean', 'nom': 'Cagne'},
#  {'prenom': 'Henri', 'nom': 'Caillavet'},
#  {'prenom': 'Raoul', 'nom': 'Calas'},
#  {'prenom': 'René', 'nom': 'Cance'},
#  {'prenom': 'Marius', 'nom': 'Cartier'},
#  {'prenom': 'Marcel', 'nom': 'Cartier'},
#  {'prenom': 'Laurent', 'nom': 'Casanova'},
#  {'prenom': 'René', 'nom': 'Cassagne'},
#  {'prenom': 'Edmond', 'nom': 'Castera'},
#  {'prenom': 'Paul', 'nom': 'Cermolacce'},
#  {'prenom': 'Aimé', 'nom': 'Césaire'},
#  {'prenom': 'Jean', 'nom': 'Charlot'},
#  {'prenom': 'Roger', 'nom': 'Chatelain'},
#  {'prenom': 'Augustin', 'nom': 'Chauvet'},
#  {'prenom': 'Saïd Mohamed Ben Chech Abdallah', 'nom': 'Cheikh'},
#  {'prenom': 'André', 'nom': 'Chène'},
#  {'prenom': 'Marcel', 'nom': 'Cherrier'},
#  {'prenom': 'Pierre', 'nom': 'Clostermann'},
#  {'prenom': 'Georges', 'nom': 'Cogniot'},
#  {'prenom': 'Georges', 'nom': 'Condat'},
#  {'prenom': 'Arthur', 'nom': 'Conte'},
#  {'prenom': 'Gaston', 'nom': 'Coquel'},
#  {'prenom': 'Jean', 'nom': 'Cordillot'},
#  {'prenom': 'Maurice', 'nom': 'Cormier'},
#  {'prenom': 'Daniel', 'nom': 'Coulibaly'},
#  {'prenom': 'Robert', 'nom': 'Coutant'},
#  {'prenom': 'Jean', 'nom': 'Cristofol'},
#  {'prenom': 'Guy', 'nom': 'Cupfer'},
#  {'prenom': 'Léon', 'nom': 'Dagain'},
#  {'prenom': 'Edouard', 'nom': 'Daladier'},
#  {'prenom': 'Marcel', 'nom': 'Darou'},
#  {'prenom': 'Marcel', 'nom': 'David'},
#  {'prenom': 'Albert', 'nom': 'de Baillencourt'},
#  {'prenom': 'Pierre', 'nom': 'de Felice'},
#  {'prenom': 'Jean', 'nom': 'de Lipkowski'},
#  {'prenom': 'Vincent', 'nom': 'de Moro-Giafferri'},
#  {'prenom': 'Gaston', 'nom': 'Defferre'},
#  {'prenom': 'Auguste', 'nom': 'Defrance'},
#  {'prenom': 'Lucien', 'nom': 'Degoutte'},
#  {'prenom': 'Céline', 'nom': 'Degrond'},
#  {'prenom': 'Maurice', 'nom': 'Deixonne'},
#  {'prenom': 'René', 'nom': 'Dejean'},
#  {'prenom': 'Camille', 'nom': 'Delabre'},
#  {'prenom': 'Antoine', 'nom': 'Demusois'},
#  {'prenom': 'Alphonse', 'nom': 'Denis'},
#  {'prenom': 'Albert', 'nom': 'Denvers'},
#  {'prenom': 'Edouard', 'nom': 'Depreux'},
#  {'prenom': 'Edmond', 'nom': 'Desouches'},
#  {'prenom': 'Guy', 'nom': 'Desson'},
#  {'prenom': 'Paul', 'nom': 'Devinat'},
#  {'prenom': 'Tarsyle', 'nom': 'Dewasmes'},
#  {'prenom': 'Saïfoulaye', 'nom': 'Diallo'},
#  {'prenom': 'Jean', 'nom': 'Diat'},
#  {'prenom': 'Hamadoun', 'nom': 'Dicko'},
#  {'prenom': 'Pierre', 'nom': 'Doize'},
#  {'prenom': 'Pierre', 'nom': 'Doutrellot'},
#  {'prenom': 'Louis', 'nom': 'Dubois'},
#  {'prenom': 'Jacques', 'nom': 'Duclos'},
#  {'prenom': 'Hippolyte', 'nom': 'Ducos'},
#  {'prenom': 'André', 'nom': 'Dufour'},
#  {'prenom': 'Roland', 'nom': 'Dumas'},
#  {'prenom': 'Jeannil', 'nom': 'Dumortier'},
#  {'prenom': 'Louis', 'nom': 'Dupont'},
#  {'prenom': 'Gérard', 'nom': 'Duprat'},
#  {'prenom': 'Marc', 'nom': 'Dupuy'},
#  {'prenom': 'Jean', 'nom': 'Durroux'},
#  {'prenom': 'Roger', 'nom': 'Duveau'},
#  {'prenom': 'Eugénie', 'nom': 'Duvernois'},
#  {'prenom': 'Yvonne', 'nom': 'Estachy'},
#  {'prenom': 'Louis', 'nom': 'Eudier'},
#  {'prenom': 'Just', 'nom': 'Évrard'},
#  {'prenom': 'Jacques', 'nom': 'Faggianelli'},
#  {'prenom': 'Etienne', 'nom': 'Fajon'},
#  {'prenom': 'Roger', 'nom': 'Faraud'},
#  {'prenom': 'Maurice', 'nom': 'Faure'},
#  {'prenom': 'Jean', 'nom': 'Félix-Tchicaya'},
#  {'prenom': 'Eugène', 'nom': 'Fourvel'},
#  {'prenom': 'Marie', 'nom': 'François-Bénard'},
#  {'prenom': 'Roger', 'nom': 'Gaborit'},
#  {'prenom': 'Etienne', 'nom': 'Gagnaire'},
#  {'prenom': 'Félix', 'nom': 'Gaillard'},
#  {'prenom': 'Emilienne', 'nom': 'Galicier'},
#  {'prenom': 'Joseph', 'nom': 'Garat'},
#  {'prenom': 'Roger', 'nom': 'Garaudy'},
#  {'prenom': 'Louis', 'nom': 'Garnier'},
#  {'prenom': 'André', 'nom': 'Gautier'},
#  {'prenom': 'Albert', 'nom': 'Gazier'},
#  {'prenom': 'Raymond', 'nom': 'Gernez'},
#  {'prenom': 'François', 'nom': 'Giacobbi'},
#  {'prenom': 'Rosan', 'nom': 'Girard'},
#  {'prenom': 'Pierre', 'nom': 'Girardot'},
#  {'prenom': 'Georges', 'nom': 'Gosnat'},
#  {'prenom': 'Jean', 'nom': 'Goudoux'},
#  {'prenom': 'Félix', 'nom': 'Gouin'},
#  {'prenom': 'Robert', 'nom': 'Gourdon'},
#  {'prenom': 'Gilles', 'nom': 'Gozard'},
#  {'prenom': 'Elise', 'nom': 'Grappe'},
#  {'prenom': 'Gilles', 'nom': 'Gravoille'},
#  {'prenom': 'Fernand', 'nom': 'Grenier'},
#  {'prenom': 'Rose', 'nom': 'Guérin'},
#  {'prenom': 'Germain', 'nom': 'Guibert'},
#  {'prenom': 'Georges', 'nom': 'Guille'},
#  {'prenom': 'Marcel', 'nom': 'Guislain'},
#  {'prenom': 'Jean', 'nom': 'Guitton'},
#  {'prenom': 'Jean-Raymond', 'nom': 'Guyon'},
#  {'prenom': 'Raymond', 'nom': 'Guyot'},
#  {'prenom': 'Diori', 'nom': 'Hamani'},
#  {'prenom': 'Marcel', 'nom': 'Hamon'},
#  {'prenom': 'Olivier', 'nom': 'Harty'},
#  {'prenom': 'Henri', 'nom': 'Henneguelle'},
#  {'prenom': 'Charles', 'nom': 'Hernu'},
#  {'prenom': 'Edouard', 'nom': 'Herriot'},
#  {'prenom': 'Robert', 'nom': 'Hersant'},
#  {'prenom': 'Jean', 'nom': 'Houdremont'},
#  {'prenom': 'Félix', 'nom': 'Houphouët-Boigny'},
#  {'prenom': 'Léon', 'nom': 'Hovnanian'},
#  {'prenom': 'Emile', 'nom': 'Hugues'},
#  {'prenom': 'André', 'nom': 'Hugues'},
#  {'prenom': 'Gérard', 'nom': 'Jaquet'},
#  {'prenom': 'Bernard', 'nom': "Jourd'Huy"},
#  {'prenom': 'Pierre', 'nom': 'Juge'},
#  {'prenom': 'Gaston', 'nom': 'Julian'},
#  {'prenom': 'Georges', 'nom': 'Juskiewenski'},
#  {'prenom': 'Max', 'nom': 'Juvénal'},
#  {'prenom': 'Modibo', 'nom': 'Keita'},
#  {'prenom': 'Mamadou', 'nom': 'Konaté'},
#  {'prenom': 'Maurice', 'nom': 'Kriegel-Valrimont'},
#  {'prenom': 'Robert', 'nom': 'Lacoste'},
#  {'prenom': 'Henri', 'nom': 'Laforest'},
#  {'prenom': 'Charles', 'nom': 'Lamarque-Cando'},
#  {'prenom': 'Lucien', 'nom': 'Lambert'},
#  {'prenom': 'René', 'nom': 'Lamps'},
#  {'prenom': 'Pierre-Olivier', 'nom': 'Lapie'},
#  {'prenom': 'Pierre', 'nom': 'Lareppe'},
#  {'prenom': 'Tony', 'nom': 'Larue'},
#  {'prenom': 'Jean', 'nom': 'Le Bail'},
#  {'prenom': 'Guillaume', 'nom': 'Le Caroff'},
#  {'prenom': 'André', 'nom': 'Le Floch'},
#  {'prenom': 'Alexis', 'nom': 'Le Strat'},
#  {'prenom': 'André', 'nom': 'Le Troquer'},
#  {'prenom': 'Claude', 'nom': 'Leclercq'},
#  {'prenom': 'Constant', 'nom': 'Lecoeur'},
#  {'prenom': 'Francis', 'nom': 'Leenhardt'},
#  {'prenom': 'Raymond', 'nom': 'Lefranc'},
#  {'prenom': 'Fernand', 'nom': 'Legagneux'},
#  {'prenom': 'Max', 'nom': 'Lejeune'},
#  {'prenom': 'Rachel', 'nom': 'Lempereur'},
#  {'prenom': 'André', 'nom': 'Lenormand'},
#  {'prenom': 'Roland', 'nom': 'Leroy'},
#  {'prenom': 'Jean', 'nom': 'Lespiau'},
#  {'prenom': 'Léandre', 'nom': 'Letoquart'},
#  {'prenom': 'Marcel', 'nom': 'Levindrey'},
#  {'prenom': 'Gabriel', 'nom': 'Lisette'},
#  {'prenom': 'Jean', 'nom': 'Llante'},
#  {'prenom': 'Kléber', 'nom': 'Loustau'},
#  {'prenom': 'Adrien', 'nom': 'Mabrut'},
#  {'prenom': 'Pierre', 'nom': 'Mailhé'},
#  {'prenom': 'Alfred', 'nom': 'Malleret-Joinville'},
#  {'prenom': 'Robert', 'nom': 'Manceau'},
#  {'prenom': 'André', 'nom': 'Mancey'},
#  {'prenom': 'Hervé', 'nom': 'Mao'},
#  {'prenom': 'Charles', 'nom': 'Margueritte'},
#  {'prenom': 'René', 'nom': 'Mariat'},
#  {'prenom': 'André', 'nom': 'Marie'},
#  {'prenom': 'Fernand', 'nom': 'Marin'},
#  {'prenom': 'André', 'nom': 'Maroselli'},
#  {'prenom': 'Georges', 'nom': 'Marrane'},
#  {'prenom': 'Henri', 'nom': 'Martel'},
#  {'prenom': 'Gilbert', 'nom': 'Martin'},
#  {'prenom': 'Madeleine', 'nom': 'Marzin'},
#  {'prenom': 'Jean', 'nom': 'Masse'},
#  {'prenom': 'Jean', 'nom': 'Masson'},
#  {'prenom': 'Albert', 'nom': 'Maton'},
#  {'prenom': 'Daniel', 'nom': 'Mayer'},
#  {'prenom': 'Antoine', 'nom': 'Mazier'},
#  {'prenom': 'Fernand', 'nom': 'Mazuez'},
#  {'prenom': 'André-Marie', 'nom': 'Mbida'},
#  {'prenom': 'Pierre', 'nom': 'Mendès'},
#  {'prenom': 'André', 'nom': 'Mercier'},
#  {'prenom': 'Marcel', 'nom': 'Mérigonde'},
#  {'prenom': 'Toussaint', 'nom': 'Merle'},
#  {'prenom': 'Pierre', 'nom': 'Métayer'},
#  {'prenom': 'Jean', 'nom': 'Meunier'},
#  {'prenom': 'Maurice', 'nom': 'Michel'},
#  {'prenom': 'Lucien', 'nom': 'Midol'},
#  {'prenom': 'Jean', 'nom': 'Minjoz'},
#  {'prenom': 'François', 'nom': 'Mitterrand'},
#  {'prenom': 'Jules', 'nom': 'Moch'},
#  {'prenom': 'Guy', 'nom': 'Mollet'},
#  {'prenom': 'Raymond', 'nom': 'Mondon'},
#  {'prenom': 'Pierre', 'nom': 'Monnerville'},
#  {'prenom': 'Jean', 'nom': 'Montalat'},
#  {'prenom': 'Eugène', 'nom': 'Montel'},
#  {'prenom': 'Albert', 'nom': 'Mora'},
#  {'prenom': 'Roger', 'nom': 'Morève'},
#  {'prenom': 'André', 'nom': 'Morice'},
#  {'prenom': 'Adrien', 'nom': 'Mouton'},
#  {'prenom': 'Auguste', 'nom': 'Mudry'},
#  {'prenom': 'Arthur', 'nom': 'Musmeaux'},
#  {'prenom': 'Marcel-Edmond', 'nom': 'Naegelen'},
#  {'prenom': 'Pierre', 'nom': 'Naudet'},
#  {'prenom': 'Jules', 'nom': 'Ninine'},
#  {'prenom': 'Marcel', 'nom': 'Noël'},
#  {'prenom': 'Arthur', 'nom': 'Notebart'},
#  {'prenom': 'René', 'nom': 'Pagès'},
#  {'prenom': 'Jean', 'nom': 'Palméro'},
#  {'prenom': 'Claude', 'nom': 'Panier'},
#  {'prenom': 'André', 'nom': 'Parmentier'},
#  {'prenom': 'Gabriel', 'nom': 'Paul'},
#  {'prenom': 'Bernard', 'nom': 'Paumier'},
#  {'prenom': 'Marcel', 'nom': 'Pélissou'},
#  {'prenom': 'Alphonse', 'nom': 'Penven'},
#  {'prenom': 'Maurice', 'nom': 'Perche'},
#  {'prenom': 'Mathilde', 'nom': 'Péri'},
#  {'prenom': 'Yves', 'nom': 'Péron'},
#  {'prenom': 'André', 'nom': 'Pierrard'},
#  {'prenom': 'Jacques', 'nom': 'Piette'},
#  {'prenom': 'Christian', 'nom': 'Pineau'},
#  {'prenom': 'Georges', 'nom': 'Pirot'},
#  {'prenom': 'Roland', 'nom': 'Plaisance'},
#  {'prenom': 'René', 'nom': 'Pleven'},
#  {'prenom': 'Henri', 'nom': 'Pourtalet'},
#  {'prenom': 'Pierre', 'nom': 'Pranchère'},
#  {'prenom': 'Tanguy', 'nom': 'Prigent'},
#  {'prenom': 'Jeannette', 'nom': 'Prin'},
#  {'prenom': 'Jean', 'nom': 'Pronteau'},
#  {'prenom': 'Louis', 'nom': 'Prot'},
#  {'prenom': 'Victor', 'nom': 'Provo'},
#  {'prenom': 'Henri', 'nom': 'Queuille'},
#  {'prenom': 'Maria', 'nom': 'Rabaté'},
#  {'prenom': 'Paul', 'nom': 'Ramadier'},
#  {'prenom': 'Arthur', 'nom': 'Ramette'},
#  {'prenom': 'Edouard', 'nom': 'Ramonet'},
#  {'prenom': 'Roger', 'nom': 'Ranoux'},
#  {'prenom': 'René', 'nom': 'Regaudie'},
#  {'prenom': 'Adrien', 'nom': 'Renard'},
#  {'prenom': 'Renée', 'nom': 'Reyraud'},
#  {'prenom': 'Jean', 'nom': 'Rieu'},
#  {'prenom': 'Germain', 'nom': 'Rincent'},
#  {'prenom': 'Gilberte', 'nom': 'Roca'},
#  {'prenom': 'Waldeck', 'nom': 'Rochet'},
#  {'prenom': 'Jacques', 'nom': 'Rolland'},
#  {'prenom': 'Félix', 'nom': 'Roquefort'},
#  {'prenom': 'Roger', 'nom': 'Roucaute'},
#  {'prenom': 'Gabriel', 'nom': 'Roucaute'},
#  {'prenom': 'Charles', 'nom': 'Ruff'},
#  {'prenom': 'Hubert', 'nom': 'Ruffe'},
#  {'prenom': 'Marcelle', 'nom': 'Rumeau'},
#  {'prenom': 'Léon', 'nom': 'Sagnol'},
#  {'prenom': 'Raoul', 'nom': 'Sauer'},
#  {'prenom': 'André', 'nom': 'Savard'},
#  {'prenom': 'Alain', 'nom': 'Savary'},
#  {'prenom': 'Pierre', 'nom': 'Ségelle'},
#  {'prenom': 'Fily-Dabo', 'nom': 'Sissoko'},
#  {'prenom': 'Michel', 'nom': 'Soulié'},
#  {'prenom': 'Pierre', 'nom': 'Souquès'},
#  {'prenom': 'André', 'nom': 'Soury'},
#  {'prenom': 'Henri', 'nom': 'Thamier'},
#  {'prenom': 'Marcel', 'nom': 'Thibaud'},
#  {'prenom': 'Eugène', 'nom': 'Thomas'},
#  {'prenom': 'Ennemond', 'nom': 'Thoral'},
#  {'prenom': 'Maurice', 'nom': 'Thorez'},
#  {'prenom': 'Camille', 'nom': 'Titeux'},
#  {'prenom': 'Marie', 'nom': 'Tony-Révillon'},
#  {'prenom': 'Sékou', 'nom': 'Touré'},
#  {'prenom': 'André', 'nom': 'Tourné'},
#  {'prenom': 'Auguste', 'nom': 'Tourtaud'},
#  {'prenom': 'Raphaël', 'nom': 'Trémouilhe'},
#  {'prenom': 'Jean', 'nom': 'Tricart'},
#  {'prenom': 'Philibert', 'nom': 'Tsiranana'},
#  {'prenom': 'René', 'nom': 'Tys'},
#  {'prenom': 'Marie-Claude', 'nom': 'Vaillant-Couturier'},
#  {'prenom': 'Camille', 'nom': 'Vallin'},
#  {'prenom': 'Francis', 'nom': 'Vals'},
#  {'prenom': 'Henri', 'nom': 'Védrines'},
#  {'prenom': 'Robert', 'nom': 'Verdier'},
#  {'prenom': 'Paul', 'nom': 'Vergès'},
#  {'prenom': 'Jeannette', 'nom': 'Vermeersch-Thorez'},
#  {'prenom': 'Emmanuel', 'nom': 'Véry-Hermence'},
#  {'prenom': 'Pierre', 'nom': 'Villon-Ginsburger'},
#  {'prenom': 'André', 'nom': 'Vuillien'}]

# %%
import re

# Orateurs issus de notre dictionnaire
orateurs = deputes_gauche_dict3

# Préparation des noms complets pour la recherche regex
noms_complets = ["{} {}".format(orateur['prenom'], orateur['nom']) for orateur in orateurs]

# Lecture du fichier
with open('débats1958_1.txt', 'r') as fichier:
    texte = fichier.read()

# Compte des occurences pour chaque député
for nom_complet in noms_complets:
    occurences = len(re.findall(re.escape(nom_complet), texte))
    print(f"Le député {nom_complet} est mentionné {occurences} fois.")
# Out:
# Le député Paul Alduy est mentionné 0 fois.
# Le député Adrien André est mentionné 0 fois.
# Le député Gustave Ansart est mentionné 0 fois.
# Le député Paul Anxionnaz est mentionné 0 fois.
# Le député René Arbeltier est mentionné 0 fois.
# Le député Franck Arnal est mentionné 0 fois.
# Le député Pascal Arrighi est mentionné 0 fois.
# Le député Achille Auban est mentionné 0 fois.
# Le député Raphaël Babet est mentionné 0 fois.
# Le député Vincent Badie est mentionné 0 fois.
# Le député Robert Ballanger est mentionné 0 fois.
# Le député Marcel Barbot est mentionné 0 fois.
# Le député Joseph dit Virgile Barel est mentionné 0 fois.
# Le député Diawadou Barry est mentionné 0 fois.
# Le député André Barthélémy est mentionné 0 fois.
# Le député Jean Bartolini est mentionné 0 fois.
# Le député Alexandre Baurens est mentionné 0 fois.
# Le député Jean Baylet est mentionné 0 fois.
# Le député Lucien Bégouin est mentionné 0 fois.
# Le député Maurice Béné est mentionné 0 fois.
# Le député Charles Benoist est mentionné 0 fois.
# Le député Alcide Benoit est mentionné 0 fois.
# Le député Alix Berthet est mentionné 0 fois.
# Le député Pierre Besset est mentionné 0 fois.
# Le député Paul Billat est mentionné 0 fois.
# Le député René Billères est mentionné 0 fois.
# Le député François Billoux est mentionné 0 fois.
# Le député Jean Binot est mentionné 0 fois.
# Le député Léopold Bissol est mentionné 0 fois.
# Le député André Blondeau est mentionné 0 fois.
# Le député Albert Boccagny est mentionné 0 fois.
# Le député Barema Bocoum est mentionné 0 fois.
# Le député Roger Boisseau est mentionné 0 fois.
# Le député André Bonnaire est mentionné 0 fois.
# Le député Edouard Bonnefous est mentionné 5 fois.
# Le député Florimond Bonte est mentionné 0 fois.
# Le député Jean Bouhey est mentionné 0 fois.
# Le député Alphonse Bouloux est mentionné 0 fois.
# Le député Henri Bourbon est mentionné 0 fois.
# Le député Maurice Bourgès-Maunoury est mentionné 0 fois.
# Le député Madeleine Boutard est mentionné 0 fois.
# Le député Rémy Boutavant est mentionné 0 fois.
# Le député Henri Briffod est mentionné 0 fois.
# Le député Patrice Brocas est mentionné 0 fois.
# Le député Louis Bruelle est mentionné 0 fois.
# Le député Marcel Cachin est mentionné 0 fois.
# Le député Jean Cagne est mentionné 0 fois.
# Le député Henri Caillavet est mentionné 0 fois.
# Le député Raoul Calas est mentionné 0 fois.
# Le député René Cance est mentionné 0 fois.
# Le député Marius Cartier est mentionné 0 fois.
# Le député Marcel Cartier est mentionné 0 fois.
# Le député Laurent Casanova est mentionné 0 fois.
# Le député René Cassagne est mentionné 0 fois.
# Le député Edmond Castera est mentionné 0 fois.
# Le député Paul Cermolacce est mentionné 0 fois.
# Le député Aimé Césaire est mentionné 0 fois.
# Le député Jean Charlot est mentionné 0 fois.
# Le député Roger Chatelain est mentionné 0 fois.
# Le député Augustin Chauvet est mentionné 0 fois.
# Le député Saïd Mohamed Ben Chech Abdallah Cheikh est mentionné 0 fois.
# Le député André Chène est mentionné 0 fois.
# Le député Marcel Cherrier est mentionné 0 fois.
# Le député Pierre Clostermann est mentionné 0 fois.
# Le député Georges Cogniot est mentionné 0 fois.
# Le député Georges Condat est mentionné 0 fois.
# Le député Arthur Conte est mentionné 0 fois.
# Le député Gaston Coquel est mentionné 0 fois.
# Le député Jean Cordillot est mentionné 0 fois.
# Le député Maurice Cormier est mentionné 0 fois.
# Le député Daniel Coulibaly est mentionné 0 fois.
# Le député Robert Coutant est mentionné 0 fois.
# Le député Jean Cristofol est mentionné 0 fois.
# Le député Guy Cupfer est mentionné 0 fois.
# Le député Léon Dagain est mentionné 0 fois.
# Le député Edouard Daladier est mentionné 0 fois.
# Le député Marcel Darou est mentionné 0 fois.
# Le député Marcel David est mentionné 0 fois.
# Le député Albert de Baillencourt est mentionné 0 fois.
# Le député Pierre de Felice est mentionné 0 fois.
# Le député Jean de Lipkowski est mentionné 0 fois.
# Le député Vincent de Moro-Giafferri est mentionné 0 fois.
# Le député Gaston Defferre est mentionné 0 fois.
# Le député Auguste Defrance est mentionné 0 fois.
# Le député Lucien Degoutte est mentionné 0 fois.
# Le député Céline Degrond est mentionné 0 fois.
# Le député Maurice Deixonne est mentionné 0 fois.
# Le député René Dejean est mentionné 0 fois.
# Le député Camille Delabre est mentionné 0 fois.
# Le député Antoine Demusois est mentionné 0 fois.
# Le député Alphonse Denis est mentionné 0 fois.
# Le député Albert Denvers est mentionné 0 fois.
# Le député Edouard Depreux est mentionné 0 fois.
# Le député Edmond Desouches est mentionné 0 fois.
# Le député Guy Desson est mentionné 0 fois.
# Le député Paul Devinat est mentionné 0 fois.
# Le député Tarsyle Dewasmes est mentionné 0 fois.
# Le député Saïfoulaye Diallo est mentionné 0 fois.
# Le député Jean Diat est mentionné 0 fois.
# Le député Hamadoun Dicko est mentionné 0 fois.
# Le député Pierre Doize est mentionné 0 fois.
# Le député Pierre Doutrellot est mentionné 0 fois.
# Le député Louis Dubois est mentionné 0 fois.
# Le député Jacques Duclos est mentionné 0 fois.
# Le député Hippolyte Ducos est mentionné 0 fois.
# Le député André Dufour est mentionné 0 fois.
# Le député Roland Dumas est mentionné 0 fois.
# Le député Jeannil Dumortier est mentionné 0 fois.
# Le député Louis Dupont est mentionné 1 fois.
# Le député Gérard Duprat est mentionné 0 fois.
# Le député Marc Dupuy est mentionné 0 fois.
# Le député Jean Durroux est mentionné 0 fois.
# Le député Roger Duveau est mentionné 0 fois.
# Le député Eugénie Duvernois est mentionné 0 fois.
# Le député Yvonne Estachy est mentionné 0 fois.
# Le député Louis Eudier est mentionné 0 fois.
# Le député Just Évrard est mentionné 0 fois.
# Le député Jacques Faggianelli est mentionné 0 fois.
# Le député Etienne Fajon est mentionné 0 fois.
# Le député Roger Faraud est mentionné 0 fois.
# Le député Maurice Faure est mentionné 0 fois.
# Le député Jean Félix-Tchicaya est mentionné 0 fois.
# Le député Eugène Fourvel est mentionné 0 fois.
# Le député Marie François-Bénard est mentionné 0 fois.
# Le député Roger Gaborit est mentionné 0 fois.
# Le député Etienne Gagnaire est mentionné 0 fois.
# Le député Félix Gaillard est mentionné 0 fois.
# Le député Emilienne Galicier est mentionné 0 fois.
# Le député Joseph Garat est mentionné 0 fois.
# Le député Roger Garaudy est mentionné 0 fois.
# Le député Louis Garnier est mentionné 0 fois.
# Le député André Gautier est mentionné 0 fois.
# Le député Albert Gazier est mentionné 0 fois.
# Le député Raymond Gernez est mentionné 0 fois.
# Le député François Giacobbi est mentionné 0 fois.
# Le député Rosan Girard est mentionné 0 fois.
# Le député Pierre Girardot est mentionné 0 fois.
# Le député Georges Gosnat est mentionné 0 fois.
# Le député Jean Goudoux est mentionné 0 fois.
# Le député Félix Gouin est mentionné 0 fois.
# Le député Robert Gourdon est mentionné 0 fois.
# Le député Gilles Gozard est mentionné 0 fois.
# Le député Elise Grappe est mentionné 0 fois.
# Le député Gilles Gravoille est mentionné 0 fois.
# Le député Fernand Grenier est mentionné 0 fois.
# Le député Rose Guérin est mentionné 0 fois.
# Le député Germain Guibert est mentionné 0 fois.
# Le député Georges Guille est mentionné 0 fois.
# Le député Marcel Guislain est mentionné 0 fois.
# Le député Jean Guitton est mentionné 0 fois.
# Le député Jean-Raymond Guyon est mentionné 0 fois.
# Le député Raymond Guyot est mentionné 0 fois.
# Le député Diori Hamani est mentionné 1 fois.
# Le député Marcel Hamon est mentionné 0 fois.
# Le député Olivier Harty est mentionné 0 fois.
# Le député Henri Henneguelle est mentionné 0 fois.
# Le député Charles Hernu est mentionné 0 fois.
# Le député Edouard Herriot est mentionné 0 fois.
# Le député Robert Hersant est mentionné 0 fois.
# Le député Jean Houdremont est mentionné 0 fois.
# Le député Félix Houphouët-Boigny est mentionné 0 fois.
# Le député Léon Hovnanian est mentionné 0 fois.
# Le député Emile Hugues est mentionné 0 fois.
# Le député André Hugues est mentionné 0 fois.
# Le député Gérard Jaquet est mentionné 0 fois.
# Le député Bernard Jourd'Huy est mentionné 0 fois.
# Le député Pierre Juge est mentionné 0 fois.
# Le député Gaston Julian est mentionné 0 fois.
# Le député Georges Juskiewenski est mentionné 0 fois.
# Le député Max Juvénal est mentionné 0 fois.
# Le député Modibo Keita est mentionné 0 fois.
# Le député Mamadou Konaté est mentionné 0 fois.
# Le député Maurice Kriegel-Valrimont est mentionné 0 fois.
# Le député Robert Lacoste est mentionné 0 fois.
# Le député Henri Laforest est mentionné 0 fois.
# Le député Charles Lamarque-Cando est mentionné 0 fois.
# Le député Lucien Lambert est mentionné 0 fois.
# Le député René Lamps est mentionné 0 fois.
# Le député Pierre-Olivier Lapie est mentionné 2 fois.
# Le député Pierre Lareppe est mentionné 0 fois.
# Le député Tony Larue est mentionné 0 fois.
# Le député Jean Le Bail est mentionné 0 fois.
# Le député Guillaume Le Caroff est mentionné 0 fois.
# Le député André Le Floch est mentionné 0 fois.
# Le député Alexis Le Strat est mentionné 0 fois.
# Le député André Le Troquer est mentionné 1 fois.
# Le député Claude Leclercq est mentionné 0 fois.
# Le député Constant Lecoeur est mentionné 0 fois.
# Le député Francis Leenhardt est mentionné 0 fois.
# Le député Raymond Lefranc est mentionné 0 fois.
# Le député Fernand Legagneux est mentionné 0 fois.
# Le député Max Lejeune est mentionné 0 fois.
# Le député Rachel Lempereur est mentionné 0 fois.
# Le député André Lenormand est mentionné 0 fois.
# Le député Roland Leroy est mentionné 0 fois.
# Le député Jean Lespiau est mentionné 0 fois.
# Le député Léandre Letoquart est mentionné 0 fois.
# Le député Marcel Levindrey est mentionné 0 fois.
# Le député Gabriel Lisette est mentionné 0 fois.
# Le député Jean Llante est mentionné 0 fois.
# Le député Kléber Loustau est mentionné 0 fois.
# Le député Adrien Mabrut est mentionné 0 fois.
# Le député Pierre Mailhé est mentionné 0 fois.
# Le député Alfred Malleret-Joinville est mentionné 0 fois.
# Le député Robert Manceau est mentionné 0 fois.
# Le député André Mancey est mentionné 1 fois.
# Le député Hervé Mao est mentionné 0 fois.
# Le député Charles Margueritte est mentionné 0 fois.
# Le député René Mariat est mentionné 0 fois.
# Le député André Marie est mentionné 0 fois.
# Le député Fernand Marin est mentionné 0 fois.
# Le député André Maroselli est mentionné 0 fois.
# Le député Georges Marrane est mentionné 0 fois.
# Le député Henri Martel est mentionné 0 fois.
# Le député Gilbert Martin est mentionné 0 fois.
# Le député Madeleine Marzin est mentionné 0 fois.
# Le député Jean Masse est mentionné 0 fois.
# Le député Jean Masson est mentionné 0 fois.
# Le député Albert Maton est mentionné 0 fois.
# Le député Daniel Mayer est mentionné 0 fois.
# Le député Antoine Mazier est mentionné 0 fois.
# Le député Fernand Mazuez est mentionné 0 fois.
# Le député André-Marie Mbida est mentionné 0 fois.
# Le député Pierre Mendès est mentionné 0 fois.
# Le député André Mercier est mentionné 0 fois.
# Le député Marcel Mérigonde est mentionné 0 fois.
# Le député Toussaint Merle est mentionné 0 fois.
# Le député Pierre Métayer est mentionné 0 fois.
# Le député Jean Meunier est mentionné 0 fois.
# Le député Maurice Michel est mentionné 0 fois.
# Le député Lucien Midol est mentionné 0 fois.
# Le député Jean Minjoz est mentionné 0 fois.
# Le député François Mitterrand est mentionné 0 fois.
# Le député Jules Moch est mentionné 0 fois.
# Le député Guy Mollet est mentionné 0 fois.
# Le député Raymond Mondon est mentionné 1 fois.
# Le député Pierre Monnerville est mentionné 0 fois.
# Le député Jean Montalat est mentionné 0 fois.
# Le député Eugène Montel est mentionné 0 fois.
# Le député Albert Mora est mentionné 0 fois.
# Le député Roger Morève est mentionné 0 fois.
# Le député André Morice est mentionné 0 fois.
# Le député Adrien Mouton est mentionné 0 fois.
# Le député Auguste Mudry est mentionné 0 fois.
# Le député Arthur Musmeaux est mentionné 0 fois.
# Le député Marcel-Edmond Naegelen est mentionné 0 fois.
# Le député Pierre Naudet est mentionné 0 fois.
# Le député Jules Ninine est mentionné 0 fois.
# Le député Marcel Noël est mentionné 0 fois.
# Le député Arthur Notebart est mentionné 0 fois.
# Le député René Pagès est mentionné 0 fois.
# Le député Jean Palméro est mentionné 0 fois.
# Le député Claude Panier est mentionné 0 fois.
# Le député André Parmentier est mentionné 0 fois.
# Le député Gabriel Paul est mentionné 0 fois.
# Le député Bernard Paumier est mentionné 0 fois.
# Le député Marcel Pélissou est mentionné 0 fois.
# Le député Alphonse Penven est mentionné 0 fois.
# Le député Maurice Perche est mentionné 0 fois.
# Le député Mathilde Péri est mentionné 0 fois.
# Le député Yves Péron est mentionné 0 fois.
# Le député André Pierrard est mentionné 0 fois.
# Le député Jacques Piette est mentionné 0 fois.
# Le député Christian Pineau est mentionné 0 fois.
# Le député Georges Pirot est mentionné 0 fois.
# Le député Roland Plaisance est mentionné 0 fois.
# Le député René Pleven est mentionné 0 fois.
# Le député Henri Pourtalet est mentionné 0 fois.
# Le député Pierre Pranchère est mentionné 0 fois.
# Le député Tanguy Prigent est mentionné 0 fois.
# Le député Jeannette Prin est mentionné 0 fois.
# Le député Jean Pronteau est mentionné 0 fois.
# Le député Louis Prot est mentionné 0 fois.
# Le député Victor Provo est mentionné 0 fois.
# Le député Henri Queuille est mentionné 0 fois.
# Le député Maria Rabaté est mentionné 0 fois.
# Le député Paul Ramadier est mentionné 0 fois.
# Le député Arthur Ramette est mentionné 0 fois.
# Le député Edouard Ramonet est mentionné 0 fois.
# Le député Roger Ranoux est mentionné 0 fois.
# Le député René Regaudie est mentionné 0 fois.
# Le député Adrien Renard est mentionné 0 fois.
# Le député Renée Reyraud est mentionné 0 fois.
# Le député Jean Rieu est mentionné 0 fois.
# Le député Germain Rincent est mentionné 0 fois.
# Le député Gilberte Roca est mentionné 0 fois.
# Le député Waldeck Rochet est mentionné 0 fois.
# Le député Jacques Rolland est mentionné 0 fois.
# Le député Félix Roquefort est mentionné 0 fois.
# Le député Roger Roucaute est mentionné 0 fois.
# Le député Gabriel Roucaute est mentionné 0 fois.
# Le député Charles Ruff est mentionné 0 fois.
# Le député Hubert Ruffe est mentionné 0 fois.
# Le député Marcelle Rumeau est mentionné 0 fois.
# Le député Léon Sagnol est mentionné 0 fois.
# Le député Raoul Sauer est mentionné 0 fois.
# Le député André Savard est mentionné 0 fois.
# Le député Alain Savary est mentionné 0 fois.
# Le député Pierre Ségelle est mentionné 0 fois.
# Le député Fily-Dabo Sissoko est mentionné 0 fois.
# Le député Michel Soulié est mentionné 0 fois.
# Le député Pierre Souquès est mentionné 0 fois.
# Le député André Soury est mentionné 0 fois.
# Le député Henri Thamier est mentionné 0 fois.
# Le député Marcel Thibaud est mentionné 0 fois.
# Le député Eugène Thomas est mentionné 0 fois.
# Le député Ennemond Thoral est mentionné 0 fois.
# Le député Maurice Thorez est mentionné 0 fois.
# Le député Camille Titeux est mentionné 0 fois.
# Le député Marie Tony-Révillon est mentionné 0 fois.
# Le député Sékou Touré est mentionné 0 fois.
# Le député André Tourné est mentionné 0 fois.
# Le député Auguste Tourtaud est mentionné 0 fois.
# Le député Raphaël Trémouilhe est mentionné 0 fois.
# Le député Jean Tricart est mentionné 0 fois.
# Le député Philibert Tsiranana est mentionné 0 fois.
# Le député René Tys est mentionné 0 fois.
# Le député Marie-Claude Vaillant-Couturier est mentionné 0 fois.
# Le député Camille Vallin est mentionné 0 fois.
# Le député Francis Vals est mentionné 0 fois.
# Le député Henri Védrines est mentionné 0 fois.
# Le député Robert Verdier est mentionné 0 fois.
# Le député Paul Vergès est mentionné 0 fois.
# Le député Jeannette Vermeersch-Thorez est mentionné 0 fois.
# Le député Emmanuel Véry-Hermence est mentionné 0 fois.
# Le député Pierre Villon-Ginsburger est mentionné 0 fois.
# Le député André Vuillien est mentionné 0 fois.

# %% [markdown]
# Cela ne va pas, quasiment tous les députés ne sont pas mentionnés, ou très rarement.

# %% [markdown]
# #### Pour compter le nombre de caractères

# %%
filename = '/Users/charlielezin/Desktop/REN/REN_1958_1/débats1958_1.txt'  


file = open(filename, 'r')
content = file.read()
character_count = len(content)
file.close()

print("Le fichier", filename, "contient", character_count, "caractères.")
# Out:
# Le fichier /Users/charlielezin/Desktop/REN/REN_1958_1/débats1958_1.txt contient 10418584 caractères.

# %% [markdown]
# #### Tentative d'extraction des prises de paroles

# %%
import re

def extraction_discours(texte, prenoms_noms, noms):
    prenoms_noms_regex = '|'.join(prenoms_noms)
    noms_regex = '|'.join(noms)

    modele = r"(M\.|Mme|Mlle)\s+(" + prenoms_noms_regex + "|" + noms_regex + r")\.(.*?)(?=(M\.|Mme|Mlle|\())"
    
    discours = re.findall(modele, texte, re.DOTALL)
    
    return discours

def traitement_file(input_fichier, orateurs):
    with open(input_fichier, 'r') as file:
        texte = file.read()

    noms = [orateur['nom'] for orateur in orateurs]
    prenoms_noms = [f"{orateur['prenom']} {orateur['nom']}" for orateur in orateurs]

    discours = extraction_discours(texte, prenoms_noms, noms)

    for discours in discours:
        print(discours)

# Appelez la fonction avec le nom de votre fichier en entrée et la liste de dictionnaires
orateurs = deputes_gauche_dict3
traitement_file('débats1958_1.txt', orateurs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 26
#      23         print(discours)
#      25 # Appelez la fonction avec le nom de votre fichier en entrée et la liste de dictionnaires
# ---> 26 orateurs = deputes_gauche_dict3
#      27 traitement_file('débats1958_1.txt', orateurs)
#
# NameError: name 'deputes_gauche_dict3' is not defined

# %%
import re
import csv

def extraire_discours(texte, noms_complets, noms_familiaux):
    noms_complets_regex = '|'.join(noms_complets)
    noms_familiaux_regex = '|'.join(noms_familiaux)

    motif = r"(M\.|Mme|Mlle)\s+(" + noms_complets_regex + "|" + noms_familiaux_regex + r")\.(.*?)(?=(M\.|Mme|Mlle|\())"
    
    discours = re.findall(motif, texte, re.DOTALL)
    
    # Pour conserver les discours de plus d'une ligne
    discours = [d for d in discours if '\n' in d[2]]
    
    return discours

def traiter_fichier(nom_fichier_input, orateurs):
    with open(nom_fichier_input, 'r') as fichier:
        texte = fichier.read()

    noms_familiaux = [orateur['nom'] for orateur in orateurs]
    noms_complets = [f"{orateur['prenom']} {orateur['nom']}" for orateur in orateurs]

    discours = extraire_discours(texte, noms_complets, noms_familiaux)
    
    with open('discoursGauche_1958_1.csv', 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["Titre", "Nom", "Discours"])
        for d in discours:
            writer.writerow([d[0], d[1], d[2].replace('\n', ' ')])

orateurs = deputes_gauche_dict3

traiter_fichier('débats1958_1.txt', orateurs)

# %%
import re
import pandas as pd

def supprime_saut_de_ligne_avant_parentheses(texte):
    return re.sub(r"\n\(", " (", texte)

def extrait_discours(texte, noms_complets, noms_de_famille):
    noms_complets_regex = '|'.join(map(re.escape, noms_complets))
    noms_de_famille_regex = '|'.join(map(re.escape, noms_de_famille))

    motif = r"(M\.|Mme|Mlle)\s+((?:" + noms_complets_regex + r")|(?:" + noms_de_famille_regex + r"))\.(.*?)(?=(M\.|Mme|Mlle)(?:(?!\s+(?:" + noms_complets_regex + r"|(?:" + noms_de_famille_regex + r")))|\())"
    
    discours = re.findall(motif, texte, re.DOTALL)
    
    # Conserver uniquement les groupes pertinents pour chaque match
    discours = [(match[0], match[1], match[2]) for match in discours]
    
    return discours

def traite_fichier(fichier_entree, orateurs):
    with open(fichier_entree, 'r') as fichier:
        texte = fichier.read()

    texte = supprime_saut_de_ligne_avant_parentheses(texte)

    noms_de_famille = [orateur['nom'] for orateur in orateurs]
    noms_complets = ["{} {}".format(orateur['prenom'], orateur['nom']) for orateur in orateurs]

    discours = extrait_discours(texte, noms_complets, noms_de_famille)

    df_discours = pd.DataFrame(discours, columns=['titre', 'orateur', 'discours'])

    # Ecrit le DataFrame dans un fichier CSV
    df_discours.to_csv('discoursGauche_1958_1_v2.csv', index=False)

    return df_discours

orateurs = deputes_gauche_dict2

df = traite_fichier('débats1958_1.txt', orateurs)

# Affiche le DataFrame
print(df)
# Out:
#     titre    orateur                                           discours
# 0      M.      Darou                                               \n\n
# 1      M.     Dagain   \n\n10 \n\nASSEMBLEE  NATIONALE  —  SEANCE  ...
# 2      M.     Besset   \nAdoption,  au  scrutin,  des  propositions ...
# 3      M.  Ballanger   \nAdoption,  au  scrutin. \nExplications  de ...
# 4      M.    Bourbon    —  Retrait. \nDemande  de  disjonction  de  ...
# ..    ...        ...                                                ...
# 383    M.    Ségelle   \n\n• •• \n\nQUESTIONS  ECRITES \nREMISES  A...
# 384   Mme    Degrond   \nDeixonne. \nDejean. \nDélabré. \nDelachenal...
# 385   Mme  Lempereur   \nLéotard  (de). \nLe  Slrat. \nLevindrev. \n...
# 386  Mlle     Marzin   \nMaton. \nMercier  (André),  Oise \nMerle. \...
# 387    M.     Gozard          (Applaudissements \n\ngauehe.) \n\ni \n\n
#
# [388 rows x 3 columns]
